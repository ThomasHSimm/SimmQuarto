# %% [markdown]
# # Predicting Premier League Matches
# > Using Python and Random Forests to predict football matches
#
# - toc: true
# - badges: true
# - comments: true
# - categories: [Random Forests, Football, Premier League,Python]

# %% [markdown]
# ![](ghtop_images/header2.png)

# %% [markdown]
# ## Overview
#
# ### Introduction
#
# Predicting results of [English Premier League](https://en.wikipedia.org/wiki/Premier_League) using random forests for the 2022 and 2021 seasons. I will predict whether a result is a win, loss or draw.
#
# From an article about pundit versus gambling company [Pinnacle vs. Mark Lawrenson](https://www.pinnacle.com/en/betting-articles/Soccer/Mark-Lawrenson-vs-Pinnacle-Sports/VGJ296E4BSYNURUB) we have a benchmark to aim for from the 2012 season:
# - Mark Lawrenson = 52.6% accuracy
# - Pinnacle traders = 55.3% accuracy
# - Random guess = 33.3% accuracy
#
# ### Method
#
# In this data there are various parameters that can be used. The most important step is to not to use data about a current match as a predictor, but for a prediction to be based on stats from previous matches. (A couple of slight exceptions to this are below.)
#
# The predictors used here include:
# - date of match
# - home or away
# - stats from previous matches
#     - results
#     - goals scored/conceded
#     - possession/expected goals etc
# - who is playing who
# - details of match, limited to those that could be predicted beforehand
#     - referee
#     - captain
#     - formation
#     - attendance
#
# Some details on the machine learning:
#
# - A Random Forest [Classifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html) was used for analysis.
# - Data is trained on the first 28 game weeks- the other 10 are used for validation
#     - 23% validation / 77% training
# - Some data cleaning methods were performed and shown in the code
#
# ### Results
#
# - Model accuracy = 51.5% (+-1%)
#     - So the model is comparable with the results of Mark Lawrenson
# - Draws are under-represented by the model
#     - draws predicted was increased by adjusting the input parameter `class_weight` but the issue was only reduced
# - Changing input parameters was done in a semi-manual manner, obtaining the best input parameters was not easy
# - The stats from the last 5 games are the best parameters in predicting results
#
# The model is okay as it matches the accuracy from an expert pundit. But it does underperform gambing predictions.
#
# I would say the model probably needs more data to compete and outperform both of the controls consistently.
#
#
# ### Code- Prepare the data
#
# Data is prepared in a separate page- [Predicting Premier League Matches- Prepare the data](https://thomashsimm.com/pandas/football/premier%20league/python/2022/08/11/PredictingPremierLeagueMatches-PrepareTheData.html#Save-the-data)
#
#
# ## Load data and libraries

# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
cwd=os.getcwd()

# %%
cwd=os.getcwd()
folda=cwd+"/data/epl/"
dira = os.listdir(folda)
dira
# Out:
# ['dfEPL_2017.csv',
#  'dfEPL_2018.csv',
#  'dfEPL_2019.csv',
#  'dfEPL_2020.csv',
#  'dfEPL_2021.csv',
#  'epl2017-2021.csv',
#  'epl2017-2021_wivnetscore.csv']

# %%
#collapse-output

dfAll=pd.read_csv(folda+'epl2017-2021.csv')
dfAll
# Out:
#       Unnamed: 0  round  day  result_x      gf_x      ga_x         opponent_x  \
# 0              1      1   13       NaN       NaN       NaN    West Ham United
# 1              4      1   12       NaN       NaN       NaN            Burnley
# 2              5      1   11       NaN       NaN       NaN     Leicester City
# 3              7      1   12       NaN       NaN       NaN         Stoke City
# 4              9      1   13       NaN       NaN       NaN  Tottenham Hotspur
# ...          ...    ...  ...       ...       ...       ...                ...
# 1895        3788     38   22  1.666667  2.666667  0.333333    West Ham United
# 1896        3791     38   22  1.666667  1.333333  0.666667  Manchester United
# 1897        3792     38   22  1.333333  2.000000  1.666667       Leeds United
# 1898        3797     38   22  0.666667  1.000000  1.666667   Newcastle United
# 1899        3799     38   22  0.333333  0.333333  2.333333  Tottenham Hotspur
#
#          gls_x  sh_shooting_x     sot_x  ...  int_misc_y  tklw_misc_y  \
# 0          NaN            NaN       NaN  ...         NaN          NaN
# 1          NaN            NaN       NaN  ...         NaN          NaN
# 2          NaN            NaN       NaN  ...         NaN          NaN
# 3          NaN            NaN       NaN  ...         NaN          NaN
# 4          NaN            NaN       NaN  ...         NaN          NaN
# ...        ...            ...       ...  ...         ...          ...
# 1895  2.666667      15.666667  6.333333  ...   12.666667     6.666667
# 1896  1.333333      14.666667  5.000000  ...   19.333333    11.333333
# 1897  1.666667      16.000000  5.000000  ...   12.000000    11.666667
# 1898  1.000000      13.000000  4.333333  ...   14.666667    13.000000
# 1899  0.333333       9.666667  2.333333  ...   12.000000     9.666667
#
#        pkwon_y   pkcon_y      og_y    recov_y      won_y     lost_y  \
# 0          NaN       NaN       NaN        NaN        NaN        NaN
# 1          NaN       NaN       NaN        NaN        NaN        NaN
# 2          NaN       NaN       NaN        NaN        NaN        NaN
# 3          NaN       NaN       NaN        NaN        NaN        NaN
# 4          NaN       NaN       NaN        NaN        NaN        NaN
# ...        ...       ...       ...        ...        ...        ...
# 1895  0.000000  0.333333  0.333333  62.333333  14.333333  15.000000
# 1896  0.333333  0.000000  0.000000  68.000000  17.000000  13.333333
# 1897  0.000000  0.000000  0.000000  80.000000  12.000000  16.333333
# 1898  0.000000  0.000000  0.000000  64.333333  20.000000  19.000000
# 1899  0.000000  0.000000  0.000000  81.666667  23.666667  17.000000
#
#          won%_y             team_y
# 0           NaN    West Ham United
# 1           NaN            Burnley
# 2           NaN     Leicester City
# 3           NaN         Stoke City
# 4           NaN  Tottenham Hotspur
# ...         ...                ...
# 1895  49.066667    West Ham United
# 1896  56.733333  Manchester United
# 1897  42.933333       Leeds United
# 1898  48.766667   Newcastle United
# 1899  57.633333  Tottenham Hotspur
#
# [1900 rows x 344 columns]

# %%
#collapse-output
with pd.option_context("display.max_columns", None):
    display(dfAll.describe(include='all'))
# Out:
#          Unnamed: 0        round          day     result_x         gf_x  \
# count   1900.000000  1900.000000  1900.000000  1887.000000  1887.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean    1899.500000    19.500000    15.898421     0.981275     1.348613
# std     1097.253898    10.968743     9.032951     0.562990     0.821883
# min        1.000000     1.000000     1.000000     0.000000     0.000000
# 25%      950.750000    10.000000     8.000000     0.666667     0.666667
# 50%     1898.500000    19.500000    16.000000     1.000000     1.333333
# 75%     2853.500000    29.000000    23.000000     1.333333     1.666667
# max     3799.000000    38.000000    31.000000     2.000000     4.666667
#
#                ga_x opponent_x        gls_x  sh_shooting_x        sot_x  \
# count   1887.000000       1900  1887.000000    1887.000000  1887.000000
# unique          NaN         28          NaN            NaN          NaN
# top             NaN    Everton          NaN            NaN          NaN
# 75%          81.783333        8979.000000        2816.833333       186.000000
# max          90.833333       15066.666667        4280.333333       392.666667
#
#         att_passing.1_x  cmp%_passing.1_x  cmp_passing.2_x  att_passing.2_x  \
# count       1887.000000       1887.000000      1887.000000      1887.000000
# unique              NaN               NaN              NaN              NaN
# top                 NaN               NaN              NaN              NaN
# freq                NaN               NaN              NaN              NaN
# mean         180.984897         86.644515       164.931461       192.286169
# std           52.013891          3.643398        59.005557        59.215437
# min           70.000000         68.133333        55.666667        78.000000
# 25%          143.000000         84.400000       119.333333       146.666667
# 50%          172.666667         87.000000       154.000000       182.333333
# 75%          210.000000         89.250000       202.666667       230.500000
# max          416.000000         94.600000       366.666667       397.000000
#
#         cmp%_passing.2_x  cmp_passing.3_x  att_passing.3_x  cmp%_passing.3_x  \
# count        1887.000000      1887.000000      1887.000000       1887.000000
# unique               NaN              NaN              NaN               NaN
# top                  NaN              NaN              NaN               NaN
# freq                 NaN              NaN              NaN               NaN
# mean           83.897553        58.174527       100.678237         56.828052
# std             5.401759        14.684347        13.592733          8.982522
# min            63.566667        26.333333        68.000000         33.233333
# 25%            80.400000        47.333333        91.333333         50.250000
# 50%            84.700000        56.000000       100.000000         56.366667
# 75%            88.016667        67.000000       109.333333         63.116667
# max            94.266667       117.666667       164.000000         83.633333
#
#               ast_x         xa_x         kp_x  1/3_passing_x        ppa_x  \
# count   1887.000000  1887.000000  1887.000000    1887.000000  1887.000000
# unique          NaN          NaN          NaN            NaN          NaN
# top             NaN          NaN          NaN            NaN          NaN
# freq            NaN          NaN          NaN            NaN          NaN
# mean       0.935082     0.884941     8.780427      29.078520     8.121092
# std        0.666895     0.399544     2.870647      10.251511     3.403934
# min        0.000000     0.133333     1.666667      10.333333     0.333333
# 25%        0.333333     0.600000     6.666667      22.000000     5.666667
# 50%        0.666667     0.833333     8.333333      26.666667     7.333333
# 75%        1.333333     1.100000    10.666667      33.666667    10.000000
# max        4.333333     2.833333    22.000000      71.000000    24.333333
#
#             crspa_x  prog_passing_x  att_passing_types_x  \
# count   1887.000000     1887.000000          1887.000000
# unique          NaN             NaN                  NaN
# top             NaN             NaN                  NaN
# freq            NaN             NaN                  NaN
# mean       1.944709       32.064211           492.537361
# std        0.983293       10.231721           116.071850
# min        0.000000        8.000000           251.666667
# 25%        1.333333       24.666667           406.666667
# 50%        1.666667       30.333333           472.666667
# 75%        2.666667       37.500000           566.166667
# max        8.000000       76.666667           927.333333
#
#         live_passing_types_x       dead_x  fk_passing_types_x         tb_x  \
# count            1887.000000  1887.000000         1887.000000  1887.000000
# unique                   NaN          NaN                 NaN          NaN
# top                      NaN          NaN                 NaN          NaN
# freq                     NaN          NaN                 NaN          NaN
# mean              444.751899    47.785462           11.694135     0.920774
# std               116.835035     5.205801            2.417642     0.819581
# min               212.000000    32.333333            4.333333     0.000000
# 25%               358.333333    44.333333           10.000000     0.333333
# 50%               423.000000    47.666667           11.666667     0.666667
# 75%               517.500000    51.333333           13.333333     1.333333
# std           8.310211     4.019124            15.206973            13.690141
# min          19.333333    13.700000            15.666667            31.333333
# 25%          38.000000    26.766667            42.333333            55.000000
# 50%          43.333333    29.433333            51.666667            64.000000
# 75%          49.000000    32.100000            62.000000            73.666667
# max          83.000000    43.100000           122.666667           122.000000
#
#         att 3rd_defense.1_x  blocks_defense_x  sh_defense_x       shsv_x  \
# count           1887.000000       1887.000000   1887.000000  1887.000000
# unique                  NaN               NaN           NaN          NaN
# top                     NaN               NaN           NaN          NaN
# freq                    NaN               NaN           NaN          NaN
# mean              32.802862         15.953100      3.864335     0.080639
# std                8.566743          3.450404      1.723662     0.172795
# min               12.666667          6.000000      0.000000     0.000000
# 25%               26.666667         13.333333      2.666667     0.000000
# 50%               32.000000         16.000000      3.666667     0.000000
# 75%               38.000000         18.000000      5.000000     0.000000
# max               76.666667         30.666667     14.666667     1.000000
#
#              pass_x  int_defense_x        clr_x        err_x       poss_x  \
# count   1887.000000    1887.000000  1887.000000  1887.000000  1887.000000
# unique          NaN            NaN          NaN          NaN          NaN
# top             NaN            NaN          NaN          NaN          NaN
# freq            NaN            NaN          NaN          NaN          NaN
# mean      12.088765      12.303568    25.391715     0.277778    49.794471
# std        2.669393       4.950353     7.901514     0.338057     9.654077
# min        5.000000       1.666667     6.333333     0.000000    24.666667
# 25%       10.333333       8.333333    20.000000     0.000000    42.666667
# 50%       12.000000      12.333333    24.666667     0.333333    49.333333
# 75%       14.000000      15.833333    30.000000     0.333333    56.333333
# max       22.666667      31.666667    62.666667     2.666667    77.666667
#
#           touches_x    def pen_x  def 3rd_possession_x  mid 3rd_possession_x  \
# count   1887.000000  1887.000000           1887.000000           1887.000000
# unique          NaN          NaN                   NaN                   NaN
# top             NaN          NaN                   NaN                   NaN
# freq            NaN          NaN                   NaN                   NaN
# mean     613.384473    66.492316            200.964671            289.074545
# std      112.185015    11.791488             29.665480             73.462201
# min      361.666667    25.000000            116.000000            140.666667
# 25%      530.166667    58.333333            179.333333            235.666667
# 50%      596.333333    65.666667            199.333333            278.333333
# 75%      683.666667    73.666667            220.000000            328.333333
# max     1023.666667   141.000000            363.000000            598.333333
#
#         att 3rd_possession_x    att pen_x  live_possession_x  \
# count            1887.000000  1887.000000        1887.000000
# unique                   NaN          NaN                NaN
# top                      NaN          NaN                NaN
# freq                     NaN          NaN                NaN
# mean              160.185921    23.606077         566.688571
# std                47.891499     8.135065         112.874321
# min                54.666667     5.666667         324.333333
# 25%               127.666667    17.666667         483.333333
# 50%               150.000000    22.333333         547.666667
# 75%               182.333333    28.000000         637.666667
# max               367.666667    63.333333         981.333333
#
#         succ_possession_x  att_possession_x      succ%_x        #pl_x  \
# count         1887.000000       1887.000000  1887.000000  1887.000000
# unique                NaN               NaN          NaN          NaN
# top                   NaN               NaN          NaN          NaN
# freq                  NaN               NaN          NaN          NaN
# mean             9.590178         16.423688    58.240761    10.422893
# std              2.904043          4.134119     9.007144     3.056041
# min              2.666667          5.000000    28.600000     3.000000
# 75%       39.433333     0.136667     0.396667    18.166667       0.666667
# max       75.000000     0.426667     1.000000    25.033333       3.000000
#
#                pk_y  pkatt_shooting_y         xg_y       npxg_y    npxg/sh_y  \
# count   1885.000000       1885.000000  1885.000000  1885.000000  1885.000000
# unique          NaN               NaN          NaN          NaN          NaN
# top             NaN               NaN          NaN          NaN          NaN
# freq            NaN               NaN          NaN          NaN          NaN
# mean       0.106720          0.134483     1.343775     1.241813     0.101071
# std        0.192914          0.217812     0.542758     0.500615     0.028187
# min        0.000000          0.000000     0.200000     0.166667     0.033333
# 25%        0.000000          0.000000     0.966667     0.866667     0.080000
# 50%        0.000000          0.000000     1.266667     1.166667     0.096667
# 75%        0.333333          0.333333     1.633333     1.500000     0.116667
# max        1.000000          1.000000     3.666667     3.300000     0.240000
#
#              g-xg_y    np:g-xg_y       sota_y      saves_y      save%_y  \
# count   1885.000000  1885.000000  1885.000000  1885.000000  1885.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean       0.007153     0.002396     4.028559     2.772679    68.942476
# std        0.548397     0.546242     1.531216     1.180476    17.188190
# min       -1.700000    -1.700000     0.666667     0.000000    -8.333333
# 25%       -0.366667    -0.366667     3.000000     2.000000    58.566667
# 50%       -0.033333    -0.033333     4.000000     2.666667    70.000000
# 75%        0.333333     0.333333     5.000000     3.666667    80.566667
# max        2.366667     2.366667    10.333333     8.000000   100.000000
#
#                cs_y       psxg_y    psxg+/-_y  pkatt_keeper_y        pka_y  \
# count   1885.000000  1885.000000  1885.000000     1885.000000  1885.000000
# unique          NaN          NaN          NaN             NaN          NaN
# top             NaN          NaN          NaN             NaN          NaN
# freq            NaN          NaN          NaN             NaN          NaN
# mean       0.294518     1.318400     0.003899        0.133245     0.103714
# std        0.275738     0.618038     0.420442        0.219380     0.189636
# min        0.000000     0.000000    -1.800000        0.000000     0.000000
# 25%        0.000000     0.866667    -0.266667        0.000000     0.000000
# 50%        0.333333     1.266667     0.033333        0.000000     0.000000
# 75%        0.333333     1.700000     0.266667        0.333333     0.333333
# max        1.333333     3.766667     1.500000        1.500000     1.500000
#
#              pksv_y        pkm_y  cmp_keeper_y  att_keeper_y  cmp%_keeper_y  \
# count   1885.000000  1885.000000   1885.000000   1885.000000    1885.000000
# unique          NaN          NaN           NaN           NaN            NaN
# top             NaN          NaN           NaN           NaN            NaN
# freq            NaN          NaN           NaN           NaN            NaN
# mean       0.021751     0.007781      6.664633     17.180460      41.582263
# std        0.089879     0.051501      2.703961      6.855387      11.862575
# min        0.000000     0.000000      0.666667      2.333333      11.100000
# 25%        0.000000     0.000000      4.666667     11.666667      33.333333
# 50%        0.000000     0.000000      6.333333     17.333333      40.400000
# 75%        0.000000     0.000000      8.666667     22.333333      48.200000
# max        1.000000     0.666667     16.333333     42.000000      95.233333
#
#         att_keeper.1_y        thr_y    launch%_y     avglen_y  att_keeper.2_y  \
# count      1885.000000  1885.000000  1885.000000  1885.000000     1885.000000
# unique             NaN          NaN          NaN          NaN             NaN
# top                NaN          NaN          NaN          NaN             NaN
# freq               NaN          NaN          NaN          NaN             NaN
# mean         24.047303     4.079222    50.730752    42.360955        7.347834
# std           5.541456     1.641207    20.175225     9.649619        2.115403
# min          10.000000     0.333333     8.200000    22.500000        1.000000
# 25%          20.000000     3.000000    34.466667    34.500000        6.000000
# 50%          23.666667     4.000000    51.200000    41.866667        7.333333
# 75%          27.333333     5.000000    66.400000    49.666667        8.666667
# max          50.333333    10.333333   100.000000    71.666667       16.000000
#
#         launch%.1_y   avglen.1_y        opp_y        stp_y       stp%_y  \
# count   1885.000000  1885.000000  1885.000000  1885.000000  1885.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean      66.706225    52.362776     8.600973     0.653935     7.557745
# std       24.974972    13.990437     2.787519     0.525688     6.332470
# min        0.000000    10.733333     1.333333     0.000000     0.000000
# 25%       46.800000    40.966667     6.666667     0.333333     3.033333
# 50%       71.166667    54.000000     8.333333     0.666667     6.533333
# 75%       88.900000    63.933333    10.333333     1.000000    11.100000
# max      100.000000    81.833333    21.333333     3.666667    42.933333
#
#              #opa_y    avgdist_y  cmp_passing_y  att_passing_y  \
# count   1885.000000  1885.000000    1885.000000    1885.000000
# unique          NaN          NaN            NaN            NaN
# top             NaN          NaN            NaN            NaN
# freq            NaN          NaN            NaN            NaN
# mean       0.655615    14.457374     393.315915     497.116092
# std        0.567261     3.141355     120.349836     116.921562
# min        0.000000     4.000000     137.000000     235.000000
# 25%        0.333333    12.300000     305.000000     411.666667
# 50%        0.666667    14.266667     372.333333     478.666667
# 75%        1.000000    16.333333     465.666667     566.666667
# max        3.333333    40.266667     846.333333     930.666667
#
#         cmp%_passing_y  totdist_passing_y  prgdist_passing_y  cmp_passing.1_y  \
# count      1885.000000        1885.000000        1885.000000      1885.000000
# unique             NaN                NaN                NaN              NaN
# top                NaN                NaN                NaN              NaN
# freq               NaN                NaN                NaN              NaN
# mean         77.334757        7716.688859        2578.746154       160.743148
# std           6.151168        2170.967839         444.312969        51.702598
# min          58.300000        3027.000000        1359.000000        53.000000
# 25%          73.033333        6110.666667        2265.000000       123.333333
# 50%          77.666667        7365.333333        2526.333333       151.666667
# 75%          82.000000        8991.000000        2841.666667       190.000000
# max          91.066667       14734.333333        4056.666667       406.333333
#
#         att_passing.1_y  cmp%_passing.1_y  cmp_passing.2_y  att_passing.2_y  \
# count       1885.000000       1885.000000      1885.000000      1885.000000
# unique              NaN               NaN              NaN              NaN
# top                 NaN               NaN              NaN              NaN
# freq                NaN               NaN              NaN              NaN
# mean         183.147303         86.690531       166.674713       194.160389
# std           52.846013          3.671086        59.408668        59.649384
# min           68.000000         71.333333        51.000000        72.000000
# 25%          145.000000         84.366667       121.333333       149.333333
# 50%          174.333333         87.100000       157.000000       184.000000
# 75%          213.666667         89.366667       203.666667       229.666667
# max          429.333333         95.100000       356.666667       385.000000
#
#         cmp%_passing.2_y  cmp_passing.3_y  att_passing.3_y  cmp%_passing.3_y  \
# count        1885.000000      1885.000000      1885.000000       1885.000000
# unique               NaN              NaN              NaN               NaN
# top                  NaN              NaN              NaN               NaN
# freq                 NaN              NaN              NaN               NaN
# mean     617.632449    64.989744            198.262511            292.036251
# std      113.150911    11.346986             29.170312             75.558722
# min      346.000000    32.000000            112.000000            124.000000
# 25%      535.666667    57.000000            178.000000            238.000000
# 50%      599.666667    64.333333            195.666667            279.666667
# 75%      686.000000    72.000000            217.333333            334.000000
# max     1024.000000   114.666667            311.333333            651.666667
#
#         att 3rd_possession_y    att pen_y  live_possession_y  \
# count            1885.000000  1885.000000        1885.000000
# unique                   NaN          NaN                NaN
# top                      NaN          NaN                NaN
# freq                     NaN          NaN                NaN
# mean              164.680195    24.284085         570.912290
# std                47.850712     8.148257         113.983664
# min                55.000000     6.000000         303.000000
# 25%               132.000000    18.333333         489.000000
# 50%               155.333333    23.000000         551.666667
# 75%               187.666667    28.666667         639.333333
# max               382.333333    67.000000         984.666667
#
#         succ_possession_y  att_possession_y      succ%_y        #pl_y  \
# count         1885.000000       1885.000000  1885.000000  1885.000000
# unique                NaN               NaN          NaN          NaN
# top                   NaN               NaN          NaN          NaN
# freq                  NaN               NaN          NaN          NaN
# mean             9.664898         16.536693    58.282299    10.489567
# std              2.935263          4.119026     8.891462     3.069472
# min              2.000000          6.000000    22.333333     3.000000
# 25%              7.333333         13.666667    52.466667     8.333333
# 50%              9.333333         16.333333    58.266667    10.333333
# 75%             11.333333         19.000000    64.300000    12.333333
# max             26.000000         39.000000    84.433333    27.000000
#
#              megs_y    carries_y  totdist_possession_y  prgdist_possession_y  \
# count   1885.000000  1885.000000           1885.000000           1885.000000
# unique          NaN          NaN                   NaN                   NaN
# top             NaN          NaN                   NaN                   NaN
# freq            NaN          NaN                   NaN                   NaN
# mean       0.719629   385.818391           1975.821751           1064.124050
# std        0.559645   110.104248            567.762012            352.252975
# min        0.000000   142.000000            780.000000            356.000000
# 25%        0.333333   303.000000           1534.333333            796.666667
# 50%        0.666667   369.333333           1916.666667           1013.666667
# 75%        1.000000   452.333333           2354.000000           1290.000000
# max        4.000000   737.666667           4209.000000           2418.333333
#
#         prog_possession_y  1/3_possession_y        cpa_y        mis_y  \
# count         1885.000000       1885.000000  1885.000000  1885.000000
# unique                NaN               NaN          NaN          NaN
# top                   NaN               NaN          NaN          NaN
# freq                  NaN               NaN          NaN          NaN
# mean            43.414147         13.084085     4.244828    12.209372
# std             17.649311          5.005604     2.101465     2.442809
# min              9.000000          2.000000     0.000000     5.000000
# 25%             30.333333          9.666667     2.666667    10.333333
# 50%             40.000000         12.000000     4.000000    12.333333
# 75%             53.000000         15.666667     5.333333    13.666667
# max            116.000000         37.000000    14.666667    23.000000
#
#               dis_y       targ_y        rec_y       rec%_y  \
# count   1885.000000  1885.000000  1885.000000  1885.000000
# unique          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN
# mean      11.802122   468.212025   393.315915    82.592440
# std        2.752240   119.845963   120.349836     5.157349
# min        3.666667   203.000000   137.000000    61.866667
# 25%       10.000000   379.666667   305.000000    79.166667
# 50%       11.666667   448.666667   372.333333    83.133333
# 75%       13.666667   539.000000   465.666667    86.433333
# max       25.333333   914.666667   846.333333    93.333333
#
#         prog_possession.1_y       crdy_y       crdr_y      2crdy_y  \
# count           1885.000000  1885.000000  1885.000000  1885.000000
# unique                  NaN          NaN          NaN          NaN
# top                     NaN          NaN          NaN          NaN
# freq                    NaN          NaN          NaN          NaN
# mean              34.972679     1.617860     0.057913     0.022812
# std               10.905252     0.753974     0.145882     0.090107
# min                6.000000     0.000000     0.000000     0.000000
# 25%               27.000000     1.000000     0.000000     0.000000
# 50%               33.666667     1.666667     0.000000     0.000000
# 75%               41.000000     2.000000     0.000000     0.000000
# max               78.333333     5.000000     2.000000     1.000000
#
#               fls_y   fld_misc_y   off_misc_y   crs_misc_y   int_misc_y  \
# count   1885.000000  1885.000000  1885.000000  1885.000000  1885.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean      12.375066    11.976835     1.889390    12.193280    12.301503
# std        2.516177     2.584682     0.962440     3.465959     4.848354
# min        4.333333     3.666667     0.000000     3.333333     1.333333
# 25%       10.666667    10.333333     1.333333     9.666667     8.333333
# 50%       12.333333    12.000000     1.666667    12.000000    12.333333
# 75%       14.000000    13.666667     2.333333    14.333333    15.666667
# max       22.333333    22.000000     6.666667    25.666667    31.666667
#
#         tklw_misc_y      pkwon_y      pkcon_y         og_y      recov_y  \
# count   1885.000000  1885.000000  1885.000000  1885.000000  1885.000000
# unique          NaN          NaN          NaN          NaN          NaN
# top             NaN          NaN          NaN          NaN          NaN
# freq            NaN          NaN          NaN          NaN          NaN
# mean      10.777542     0.112555     0.128647     0.043590    90.371618
# std        2.283436     0.198533     0.213166     0.119223    11.291527
# min        4.333333     0.000000     0.000000     0.000000    51.666667
# 25%        9.333333     0.000000     0.000000     0.000000    82.333333
# 50%       10.666667     0.000000     0.000000     0.000000    90.000000
# 75%       12.333333     0.333333     0.333333     0.000000    98.000000
# max       19.666667     1.000000     1.500000     1.000000   126.666667
#
#               won_y       lost_y       won%_y   team_y
# count   1885.000000  1885.000000  1885.000000     1900
# unique          NaN          NaN          NaN       28
# top             NaN          NaN          NaN  Everton
# freq            NaN          NaN          NaN       95
# mean      19.201503    19.248806    49.947038      NaN
# std        5.667756     5.856177     6.246339      NaN
# min        5.000000     6.000000    28.633333      NaN
# 25%       15.000000    15.000000    45.833333      NaN
# 50%       18.666667    18.666667    49.800000      NaN
# 75%       23.000000    23.000000    53.933333      NaN
# max       43.000000    45.333333    72.166667      NaN

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from dtreeviz.trees import *
from pandas.api.types import is_string_dtype, is_numeric_dtype, is_categorical_dtype
from fastai.tabular.all import *

from sklearn.experimental import enable_halving_search_cv  # noqa
from sklearn.model_selection import HalvingRandomSearchCV

# %% [markdown]
# #### Train / Valid split
#
# In this case valid is actually test as train will be split by fits into train and valid

# %%
import copy
df=copy.copy(dfAll)
sza=np.shape(df)[0]

randAr=np.random.randint(0,100, size=sza)
cond = randAr>=15

cond = df.season<2021

train_idx = np.where( cond)[0]
valid_idx = np.where(~cond)[0]



splits = (list(train_idx),list(valid_idx))

valid_idx.shape[0]/len(df)
# Out:
# 0.2

# %%
want_binary=0
if want_binary==1:
    df.loc[df['Win_x']=='D','Win_x']='L'

# %% [markdown]
# #### Create tabular pandas & x and y values

# %%
dep_var='Win_x'

cont,cat = cont_cat_split(df, 1, dep_var=dep_var)
cat
# Out:
# ['opponent_x', 'team_x', 'opponent_y', 'team_y']

# %%
procs = [Categorify, FillMissing]
to = TabularPandas(df, procs, cat, cont, y_names=dep_var, splits=splits)

xs,y = to.train.xs,to.train.y
valid_xs,valid_y = to.valid.xs,to.valid.y

# %% [markdown]
# ## Fit the data

# %%
clf=RandomForestClassifier(random_state=42)
clf.fit(xs,y)
# Out:
# RandomForestClassifier(random_state=42)

# %%
clf.score(xs,y),clf.score(valid_xs,valid_y)
# Out:
# (1.0, 0.4921052631578947)

# %%
clf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# ### Improve hyperparameters
#
# `HalvingRandomSearchCV`, `RandomizedSearchCV` and `GridSearchCV` can be used to search for the best hyperparameters.
#
# The random ones don't go through all the options, but pick combinations randomly. So they will be quicker but may not get the best result. You may want to do the random ones to get a rough idea of parameters followed by grid search on a reduced range.
#
# The most important arguments are
# - `cv` which is the number of folds to use for cross validation (we use the default values for `cv` of 5).
# - `factor` the halving parameter (2 is used)
# - (or `n_iter` for RandomizedSearchCV, which controls the number of different combinations to try)
#
# More iterations or lower factor will cover a wider search space and more cv folds reduces the chances of overfitting, but raising each will increase the run time.

# %%
# Number of trees in random forest
n_estimators=[20,50,150,400,700]

# Number of features to consider at every split
max_features = ['log2','sqrt',None]

# Maximum number of levels in tree
max_depth=[10,  30,  70,  200, None]

# Minimum number of samples required to split a node
min_samples_split = [1.,2, 10,50]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4,10]

# Method of selecting samples for training each tree
bootstrap = [True, False]

# Weights associated with classes 
class_weight=["balanced", "balanced_subsample",None]

#Complexity parameter used for Minimal Cost-Complexity Pruning.
ccp_alpha=[0., 0.1, 0.5]

random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap,
               'class_weight':class_weight,
               'ccp_alpha' : ccp_alpha

              }

rsh = HalvingRandomSearchCV(estimator = clf, param_distributions = random_grid, \
                              random_state=42, factor = 6)# Fit the random search model
rsh.fit(xs, y)
# Out:
# HalvingRandomSearchCV(estimator=RandomForestClassifier(random_state=42),
#                       factor=6,
#                       param_distributions={'bootstrap': [True, False],
#                                            'ccp_alpha': [0.0, 0.1, 0.5],
#                                            'class_weight': ['balanced',
#                                                             'balanced_subsample',
#                                                             None],
#                                            'max_depth': [10, 30, 70, 200, None],
#                                            'max_features': ['log2', 'sqrt',
#                                                             None],
#                                            'min_samples_leaf': [1, 2, 4, 10],
#                                            'min_samples_split': [1.0, 2, 10,
#                                                                  50],
#                                            'n_estimators': [20, 50, 150, 400,
#                                                             700]},
#                       random_state=42)

# %%
results = pd.DataFrame(rsh.cv_results_)
results["params_str"] = results.params.apply(str)
results.drop_duplicates(subset=("params_str", "iter"), inplace=True)
mean_scores = results.pivot(
    index="iter", columns="params_str", values="mean_test_score"
)
ax = mean_scores.plot(legend=False, alpha=0.6)

labels = [
    f"iter={i}\nn_samples={rsh.n_resources_[i]}\nn_candidates={rsh.n_candidates_[i]}"
    for i in range(rsh.n_iterations_)
]

ax.set_xticks(range(rsh.n_iterations_))
ax.set_xticklabels(labels, rotation=45, multialignment="left")
ax.set_title("Scores of candidates over iterations")
ax.set_ylabel("mean test score", fontsize=15)
ax.set_xlabel("iterations", fontsize=15)
plt.tight_layout()
plt.show()

# %%
print(rsh.best_params_)
def evaluate(model, test_features, test_labels):
    predictions = model.predict(test_features)
    errors = abs(predictions - test_labels)
    mape = 100 * np.mean(errors / test_labels)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))
    
    return accuracy
best_random = rsh.best_estimator_

mm = best_random.predict(valid_xs)



print(best_random.get_params())



print("\nThe score for predictions on the 2021 season (not shown to training data) is:\n\
      {:.3f}\n\
\nThe predictions for the training data is:\n\
      {:.3f}".format(best_random.score(valid_xs, valid_y),best_random.score(xs, y)) )
# Out:
# {'n_estimators': 50, 'min_samples_split': 50, 'min_samples_leaf': 2, 'max_features': None, 'max_depth': None, 'class_weight': None, 'ccp_alpha': 0.0, 'bootstrap': True}
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 50, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 50, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}
#
# The score for predictions on the 2021 season (not shown to training data) is:
#       0.532
#
# The predictions for the training data is:
#       0.853

# %% [markdown]
# ## Look at the predictions

# %%
#clf rsh
pred=clf.predict(xs)
pred_valid=clf.predict(valid_xs)

# [(y[i],df['Win_x'].iloc[i]) for i in range(5)]
[(y[i],df['Win_x'].iloc[i],pred[i]) for i in range(5)]
# Out:
# [(2, 'W', 2), (1, 'L', 1), (2, 'W', 2), (2, 'W', 2), (1, 'L', 1)]

# %%
plt.hist(pred[y==1]-1,width=.1,align='left',linewidth=2,linestyle='-.',
         facecolor='none',edgecolor='b')#loss
plt.hist(pred[y==0],width=.1,align='mid',linewidth=2,linestyle='-',
         facecolor='none',edgecolor='r')#draw
plt.hist(pred[y==2]-2,width=.1,align='left',linewidth=2,linestyle='--',
         facecolor='none',edgecolor='k')#win

# Draw=0
# Win=2
# Loss=1
plt.legend(['Loss','Draw','Win'])
pc_loss=int(100*len(y[y==1])/len(pred))
pc_win=int(100*len(y[y==2])/len(pred))
pc_draw=int(100*len(y[y==0])/len(pred))

pc_lossP=int(100*len(pred[pred==1])/len(pred))
pc_winP=int(100*len(pred[pred==2])/len(pred))
pc_drawP=int(100*len(pred[pred==0])/len(pred))

print('win PC actual {} pred {}\n\
loss PC actual {} pred {}\n\
draw PC actual {} pred {}'.format(pc_loss,pc_lossP,pc_win,pc_winP,pc_draw,pc_drawP))
# Out:
# win PC actual 33 pred 33
# loss PC actual 44 pred 44
# draw PC actual 22 pred 22

# %%
plt.hist(pred_valid[valid_y==1]-1,width=.1,align='left',linewidth=2,linestyle='-.',
         facecolor='none',edgecolor='b')#loss
plt.hist(pred_valid[valid_y==0],width=.1,align='mid',linewidth=2,linestyle='-',
         facecolor='none',edgecolor='r')#draw
plt.hist(pred_valid[valid_y==2]-2,width=.1,align='left',linewidth=2,linestyle='--',
         facecolor='none',edgecolor='k')#win

# Draw=0
# Win=2
# Loss=1
plt.legend(['Loss','Draw','Win'])


pc_loss=int(100*len(valid_y[valid_y==1])/len(pred_valid))
pc_win=int(100*len(valid_y[valid_y==2])/len(pred_valid))
pc_draw=int(100*len(valid_y[valid_y==0])/len(pred_valid))

pc_lossP=int(100*len(pred_valid[pred_valid==1])/len(pred_valid))
pc_winP=int(100*len(pred_valid[pred_valid==2])/len(pred_valid))
pc_drawP=int(100*len(pred_valid[pred_valid==0])/len(pred_valid))

print('win PC actual {} pred {}\n\
loss PC actual {} pred {}\n\
draw PC actual {} pred {}'.format(pc_loss,pc_lossP,pc_win,pc_winP,pc_draw,pc_drawP))
# Out:
# win PC actual 33 pred 35
# loss PC actual 42 pred 61
# draw PC actual 23 pred 3

# %% [markdown]
# Model seems poor at predicting draws- none are predicted
#
# And poor at losses- 50:50 on those
#
# Because of this lets change the question to a binary one

# %% [markdown]
# ## Try with a binary question: Does the team win?

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from xgboost import XGBClassifier
from sklearn.linear_model import Ridge

# %%
df=copy.copy(dfAll)
try:
    df=df.drop(columns=['Unnamed: 0'])
except:
    pass
df=df.rename(columns={'Win_x':'Win'})
colsextraX=[x for x in df.columns if  x[-2:]!='_y']
colsextraY=[x for x in df.columns if  x[-2:]!='_x']

#collapse-hide

import copy
df=copy.copy(dfAll)

try:
    df=df.drop(columns=['Unnamed: 0'])
except:
    pass

df=df.rename(columns={'Win_x':'Win'})
df=df.loc[( ((df['round']>1) & (df['season']==2017)) | (df['season']>2017)  ) ]

#     df=df.loc[:,colsextra]

sza=np.shape(df)[0]

randAr=np.random.randint(0,100, size=sza)
cond = randAr>=15

cond = df.season<2021

train_idx = np.where( cond)[0]
valid_idx = np.where(~cond)[0]

splits = (list(train_idx),list(valid_idx))


#############
want_binary=1
if want_binary==1:
    df.loc[df['Win']=='D','Win']='L'

##############

dep_var='Win'

cont,cat = cont_cat_split(df, 1, dep_var=dep_var)

###############

procs = [Categorify, FillMissing]
to = TabularPandas(df, procs, cat, cont, y_names=dep_var, splits=splits)

xs,y = to.train.xs,to.train.y
valid_xs,valid_y = to.valid.xs,to.valid.y

# %%
def do_RF():
##############
    clf=RandomForestClassifier(random_state=42)
    clf.fit(xs,y)

    # clf.score(xs,y),clf.score(valid_xs,valid_y)
    pred_valid=clf.predict(valid_xs)
    pred=clf.predict(xs)
    
    ppred_valid=clf.predict_proba(valid_xs)
    ppred=clf.predict_proba(xs)
    
    return pred,pred_valid,ppred,ppred_valid

def do_XGB(n_estimators=1000, learning_rate=0.0001, n_jobs=100):
    # !pip install xgboost
    

    # Define the model
    my_model_2 = XGBClassifier(n_estimators=1000, learning_rate=0.01) # Your code here

    # Fit the model
    my_model_2.fit(xs, y) 

    # Get predictions
    ppred = my_model_2.predict_proba(xs)
    ppred_valid = my_model_2.predict_proba(valid_xs)
    
    pred = my_model_2.predict(xs)
    pred_valid = my_model_2.predict(valid_xs)

    return pred,pred_valid,ppred,ppred_valid 

def do_ridge():
    my_model_2 = Ridge(alpha=21)
    my_model_2.fit(xs, y)
    
    # Get predictions
    ppred = my_model_2.predict(xs)
    ppred_valid = my_model_2.predict(valid_xs)
    
    pred = my_model_2.predict(xs)
    pred_valid = my_model_2.predict(valid_xs)
    
    pred[pred>0.5]=1
    pred[pred<=0.5]=0
    
    pred_valid[pred_valid>0.5]=1
    pred_valid[pred_valid<=0.5]=0

    return pred,pred_valid , ppred,ppred_valid
    
    


pred_RF,pred_valid_RF, ppred_RF,ppred_valid_RF  = do_RF()
pred_XGB,pred_valid_XGB,ppred_XGB,ppred_valid_XGB = do_XGB()
pred_rdg,pred_valid_rdg,ppred_rdg,ppred_valid_rdg = do_ridge()
# Out:
# C:\Users\44781\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=3.35191e-10): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T

# %%
# Out:
# 10      0
# 11      0
# 12      1
# 13      0
# 14      1
#        ..
# 1515    1
# 1516    1
# 1517    0
# 1518    0
# 1519    1
# Name: Win, Length: 1510, dtype: int8

# %%
pred_combo=(ppred_valid_RF[:,1]+ppred_valid_XGB[:,1])
pred_combo[pred_combo>=1]=1
pred_combo[pred_combo<1] =0

# %%
def get_scores(nom,predd, yy):

    prec=precision_score(predd, np.array(yy)) 
    acc=accuracy_score(predd, np.array(yy))

    print("{}: accuracy = {:.2f} and precision = {:.2f}".format(nom,acc,prec))

get_scores('RF train',pred_RF, y)
get_scores('RF valid',pred_valid_RF, valid_y)
print('-----')
get_scores('XGB train',pred_XGB, y)
get_scores('XGB valid',pred_valid_XGB, valid_y)
print('-----')
get_scores('Ridge train',pred_rdg, y)
get_scores('Ridge valid',pred_valid_rdg, valid_y)
print('-----')
get_scores('Combined valid',pred_combo, valid_y)
# Out:
# RF train: accuracy = 1.00 and precision = 1.00
# RF valid: accuracy = 0.62 and precision = 0.40
# -----
# XGB train: accuracy = 1.00 and precision = 1.00
# XGB valid: accuracy = 0.61 and precision = 0.36
# -----
# Ridge train: accuracy = 0.74 and precision = 0.68
# Ridge valid: accuracy = 0.59 and precision = 0.44
# -----
# Combined valid: accuracy = 0.59 and precision = 0.33

# %%
# prec=precision_score(pred_valid, np.array(valid_y))
# print("USING WIN versus DRAW/LOSS\n\
#       \nThe score for predictions on the 2021 season (not shown to training data) is:\n\
#       {:.3f}   and precision {:.3f}\n\
# \nThe predictions for the training data is:\n\
#       {:.3f}".format(clf.score(valid_xs, valid_y),prec,clf.score(xs, y)) )

# %%
#collapse-hide
# Number of trees in random forest
n_estimators=[20,50,150,400,700]

# Number of features to consider at every split
max_features = ['log2','sqrt',None]

# Maximum number of levels in tree
max_depth=[10,  30,  70,  200, None]

# Minimum number of samples required to split a node
min_samples_split = [1.,2, 10,50]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4,10]

# Method of selecting samples for training each tree
bootstrap = [True, False]

# Weights associated with classes 
class_weight=["balanced", "balanced_subsample",None]

#Complexity parameter used for Minimal Cost-Complexity Pruning.
ccp_alpha=[0., 0.1, 0.5]

random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap,
               'class_weight':class_weight,
               'ccp_alpha' : ccp_alpha

              }

rsh = HalvingRandomSearchCV(estimator = clf, param_distributions = random_grid, \
                              random_state=42, factor = 2)# Fit the random search model
rsh.fit(xs, y)
# Out:
# HalvingRandomSearchCV(estimator=RandomForestClassifier(random_state=42),
#                       factor=2,
#                       param_distributions={'bootstrap': [True, False],
#                                            'ccp_alpha': [0.0, 0.1, 0.5],
#                                            'class_weight': ['balanced',
#                                                             'balanced_subsample',
#                                                             None],
#                                            'max_depth': [10, 30, 70, 200, None],
#                                            'max_features': ['log2', 'sqrt',
#                                                             None],
#                                            'min_samples_leaf': [1, 2, 4, 10],
#                                            'min_samples_split': [1.0, 2, 10,
#                                                                  50],
#                                            'n_estimators': [20, 50, 150, 400,
#                                                             700]},
#                       random_state=42)

# %%
print(rsh.best_params_)
def evaluate(model, test_features, test_labels):
    predictions = model.predict(test_features)
    errors = abs(predictions - test_labels)
    mape = 100 * np.mean(errors / test_labels)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))
    
    return accuracy
best_random = rsh.best_estimator_

mm = best_random.predict(valid_xs)



print(best_random.get_params())



print("\nThe score for predictions on the 2021 season (not shown to training data) is:\n\
      {:.3f}\n\
\nThe predictions for the training data is:\n\
      {:.3f}".format(best_random.score(valid_xs, valid_y),best_random.score(xs, y)) )
# Out:
# {'n_estimators': 150, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': None, 'max_depth': 10, 'class_weight': None, 'ccp_alpha': 0.0, 'bootstrap': True}
# {'bootstrap': True, 'ccp_alpha': 0.0, 'class_weight': None, 'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 4, 'min_samples_split': 10, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 150, 'n_jobs': None, 'oob_score': False, 'random_state': 42, 'verbose': 0, 'warm_start': False}
#
# The score for predictions on the 2021 season (not shown to training data) is:
#       0.624
#
# The predictions for the training data is:
#       0.976

# %%
from sklearn.metrics import precision_score

pred=best_random.predict(xs)
pred_valid=best_random.predict(valid_xs)

precision_score(pred_valid, np.array(valid_y))


# precision_score(test["target"], pred)
# Out:
# 0.3496932515337423

# %%
combined = pd.DataFrame(dict(actual = valid_y, prediction = pred_valid ))
pd.crosstab(index = combined["actual"], columns = combined['prediction'])
# Out:
# prediction    0   1
# actual
# 0           180  37
# 1           106  57

# %%
[(y[i],df['Win_x'].iloc[i],pred[i]) for i in range(5)]
# Out:
# [(1, 'W', 0), (0, 'L', 0), (1, 'W', 0), (1, 'W', 0), (0, 'L', 0)]

# %%
plt.hist(pred_valid[valid_y==0],width=.1,align='left',linewidth=2,linestyle='-.',
         facecolor='none',edgecolor='b')#
plt.hist(pred_valid[valid_y==1]-1,width=.1,align='mid',linewidth=2,linestyle='--',
         facecolor='none',edgecolor='k')#
# plt.hist(pred_valid[valid_y==2]-2,width=.1,align='left',linewidth=2,linestyle='--',
#          facecolor='none',edgecolor='k')#

# Loss=0
# Win=1

plt.legend(['Loss','Win'])

# %%
print("USING WIN versus DRAW/LOSS\n\
      \nThe score for predictions on the 2021 season (not shown to training data) is:\n\
      {:.3f}\n\
\nThe predictions for the training data is:\n\
      {:.3f}".format(rsh.score(valid_xs, valid_y),rsh.score(xs, y)) )
# Out:
# USING WIN versus DRAW/LOSS
#
# The score for predictions on the 2021 season (not shown to training data) is:
#       0.761
#
# The predictions for the training data is:
#       0.999

# %% [markdown]
# ## Look at what parameters matter in match results

# %%
def rf_feat_importance(m, df):
    return pd.DataFrame({'cols':df.columns, 'imp':m.feature_importances_}
                       ).sort_values('imp', ascending=False)

pred=best_random.predict(xs)
pred_valid=best_random.predict(valid_xs)
fi = rf_feat_importance(best_random, xs)

def plot_fi(fi):
    return fi.plot('cols', 'imp', 'barh', figsize=(12,25), legend=False,fontsize=12)

plot_fi(fi[:50]);

# %%
df.loc[10:,:]
# Out:
#      Unnamed: 0 round day  result_x      gf_x      ga_x  \
# 10            L     L   L         L         L         L
# 11           22     2  20       2.0       2.0       0.0
# 12           23     2  19       1.0       3.0       3.0
# 13           26     2  19       2.0       3.0       2.0
# 14           28     2  19       0.0       3.0       4.0
# ...         ...   ...  ..       ...       ...       ...
# 1895       3788    38  22  1.666667  2.666667  0.333333
# 1896       3791    38  22  1.666667  1.333333  0.666667
# 1897       3792    38  22  1.333333       2.0  1.666667
# 1898       3797    38  22  0.666667       1.0  1.666667
# 1899       3799    38  22  0.333333  0.333333  2.333333
#
#                     opponent_x     gls_x sh_shooting_x     sot_x  ...  \
# 10                           L         L             L         L  ...
# 11                     Chelsea       2.0          18.0       6.0  ...
# 12              Crystal Palace       3.0          13.0       4.0  ...
# 13        West Bromwich Albion       3.0          10.0       5.0  ...
# 14    Brighton and Hove Albion       3.0           6.0       4.0  ...
# ...                        ...       ...           ...       ...  ...
# 1895           West Ham United  2.666667     15.666667  6.333333  ...
# 1896         Manchester United  1.333333     14.666667       5.0  ...
# 1897              Leeds United  1.666667          16.0       5.0  ...
# 1898          Newcastle United       1.0          13.0  4.333333  ...
# 1899         Tottenham Hotspur  0.333333      9.666667  2.333333  ...
#
#      int_misc_y tklw_misc_y   pkwon_y   pkcon_y      og_y    recov_y  \
# 10            L           L         L         L         L          L
# 11          9.0         8.0       0.0       0.0       0.0       92.0
# 12         21.0        13.0       0.0       0.0       1.0      100.0
# 13         19.0        12.0       0.0       0.0       0.0       81.0
# 14         19.0         8.0       0.0       0.0       1.0       65.0
# ...         ...         ...       ...       ...       ...        ...
# 1895  12.666667    6.666667       0.0  0.333333  0.333333  62.333333
# 1896  19.333333   11.333333  0.333333       0.0       0.0       68.0
# 1897       12.0   11.666667       0.0       0.0       0.0       80.0
# 1898  14.666667        13.0       0.0       0.0       0.0  64.333333
# 1899       12.0    9.666667       0.0       0.0       0.0  81.666667
#
#           won_y     lost_y     won%_y                    team_y
# 10            L          L          L                         L
# 11         21.0       31.0       40.4                   Chelsea
# 12         19.0       19.0       50.0            Crystal Palace
# 13         21.0       21.0       50.0      West Bromwich Albion
# 14         17.0       19.0       47.2  Brighton and Hove Albion
# ...         ...        ...        ...                       ...
# 1895  14.333333       15.0  49.066667           West Ham United
# 1896       17.0  13.333333  56.733333         Manchester United
# 1897       12.0  16.333333  42.933333              Leeds United
# 1898       20.0       19.0  48.766667          Newcastle United
# 1899  23.666667       17.0  57.633333         Tottenham Hotspur
#
# [1890 rows x 344 columns]

# %% [markdown]
# ## Try as a regression problem

# %%
#collapse-output

dfAll=pd.read_csv(folda+'epl2017-2021_wivnetscore.csv')
dfAll
# Out:
#       Unnamed: 0  round  day  result_x      gf_x      ga_x         opponent_x  \
# 0              1      1   13       NaN       NaN       NaN    West Ham United
# 1              4      1   12       NaN       NaN       NaN            Burnley
# 2              5      1   11       NaN       NaN       NaN     Leicester City
# 3              7      1   12       NaN       NaN       NaN         Stoke City
# 4              9      1   13       NaN       NaN       NaN  Tottenham Hotspur
# ...          ...    ...  ...       ...       ...       ...                ...
# 1895        3788     38   22  2.333333  2.666667  0.333333    West Ham United
# 1896        3791     38   22  0.666667  1.333333  0.666667  Manchester United
# 1897        3792     38   22  0.333333  2.000000  1.666667       Leeds United
# 1898        3797     38   22 -0.666667  1.000000  1.666667   Newcastle United
# 1899        3799     38   22 -2.000000  0.333333  2.333333  Tottenham Hotspur
#
#          gls_x  sh_shooting_x     sot_x  ...  tklw_misc_y   pkwon_y   pkcon_y  \
# 0          NaN            NaN       NaN  ...          NaN       NaN       NaN
# 1          NaN            NaN       NaN  ...          NaN       NaN       NaN
# 2          NaN            NaN       NaN  ...          NaN       NaN       NaN
# 3          NaN            NaN       NaN  ...          NaN       NaN       NaN
# 4          NaN            NaN       NaN  ...          NaN       NaN       NaN
# ...        ...            ...       ...  ...          ...       ...       ...
# 1895  2.666667      15.666667  6.333333  ...     6.666667  0.000000  0.333333
# 1896  1.333333      14.666667  5.000000  ...    11.333333  0.333333  0.000000
# 1897  1.666667      16.000000  5.000000  ...    11.666667  0.000000  0.000000
# 1898  1.000000      13.000000  4.333333  ...    13.000000  0.000000  0.000000
# 1899  0.333333       9.666667  2.333333  ...     9.666667  0.000000  0.000000
#
#           og_y    recov_y      won_y     lost_y     won%_y             team_y  \
# 0          NaN        NaN        NaN        NaN        NaN    West Ham United
# 1          NaN        NaN        NaN        NaN        NaN            Burnley
# 2          NaN        NaN        NaN        NaN        NaN     Leicester City
# 3          NaN        NaN        NaN        NaN        NaN         Stoke City
# 4          NaN        NaN        NaN        NaN        NaN  Tottenham Hotspur
# ...        ...        ...        ...        ...        ...                ...
# 1895  0.333333  62.333333  14.333333  15.000000  49.066667    West Ham United
# 1896  0.000000  68.000000  17.000000  13.333333  56.733333  Manchester United
# 1897  0.000000  80.000000  12.000000  16.333333  42.933333       Leeds United
# 1898  0.000000  64.333333  20.000000  19.000000  48.766667   Newcastle United
# 1899  0.000000  81.666667  23.666667  17.000000  57.633333  Tottenham Hotspur
#
#       NetScore_y
# 0             -4
# 1              1
# 2             -1
# 3             -1
# 4              2
# ...          ...
# 1895          -2
# 1896          -1
# 1897           1
# 1898           1
# 1899           5
#
# [1900 rows x 346 columns]

# %%
df=copy.copy(dfAll)
try:
    df=df.drop(columns=['Unnamed: 0'])
except:
    pass
df=df.rename(columns={'NetScore_x':'NetScore'})
df=df.drop(columns=['Win_x','NetScore_y'])

df=df.loc[( ((df['round']>1) & (df['season']==2017)) | (df['season']>2017)  ) ]

#     df=df.loc[:,colsextra]

sza=np.shape(df)[0]

randAr=np.random.randint(0,100, size=sza)
cond = randAr>=15

cond = df.season<2021

train_idx = np.where( cond)[0]
valid_idx = np.where(~cond)[0]

splits = (list(train_idx),list(valid_idx))


##############

dep_var='NetScore'

cont,cat = cont_cat_split(df, 1, dep_var=dep_var)

###############

procs = [Categorify, FillMissing]
to = TabularPandas(df, procs, cat, cont, y_names=dep_var, splits=splits)

xs,y = to.train.xs,to.train.y
valid_xs,valid_y = to.valid.xs,to.valid.y

# %%
[x for x in df.columns]
# df[['NetScore_y','NetScore']]
# Out:
# ['round',
#  'day',
#  'result_x',
#  'gf_x',
#  'ga_x',
#  'opponent_x',
#  'gls_x',
#  'sh_shooting_x',
#  'sot_x',
#  'sot%_x',
#  'g/sh_x',
#  'g/sot_x',
#  'dist_x',
#  'fk_shooting_x',
#  'pk_x',
#  'pkatt_shooting_x',
#  'xg_x',
#  'npxg_x',
#  'npxg/sh_x',
#  'g-xg_x',
#  'np:g-xg_x',
#  'sota_x',
#  'saves_x',
#  'save%_x',
#  'cs_x',
#  'psxg_x',
#  'psxg+/-_x',
#  'pkatt_keeper_x',
#  'pka_x',
#  'pksv_x',
#  'pkm_x',
#  'cmp_keeper_x',
#  'att_keeper_x',
#  'cmp%_keeper_x',
#  'att_keeper.1_x',
#  'thr_x',
#  'launch%_x',
#  'avglen_x',
#  'att_keeper.2_x',
#  'launch%.1_x',
#  'avglen.1_x',
#  'opp_x',
#  'stp_x',
#  'stp%_x',
#  '#opa_x',
#  'avgdist_x',
#  'cmp_passing_x',
#  'att_passing_x',
#  'cmp%_passing_x',
#  'totdist_passing_x',
#  'prgdist_passing_x',
#  'cmp_passing.1_x',
#  'att_passing.1_x',
#  'cmp%_passing.1_x',
#  'cmp_passing.2_x',
#  'att_passing.2_x',
#  'cmp%_passing.2_x',
#  'cmp_passing.3_x',
#  'att_passing.3_x',
#  'cmp%_passing.3_x',
#  'ast_x',
#  'xa_x',
#  'kp_x',
#  '1/3_passing_x',
#  'ppa_x',
#  'crspa_x',
#  'prog_passing_x',
#  'att_passing_types_x',
#  'live_passing_types_x',
#  'dead_x',
#  'fk_passing_types_x',
#  'tb_x',
#  'press_passing_types_x',
#  'sw_x',
#  'crs_passing_types_x',
#  'ck_x',
#  'in_x',
#  'out_x',
#  'str_x',
#  'ground_x',
#  'low_x',
#  'high_x',
#  'left_x',
#  'right_x',
#  'head_x',
#  'ti_x',
#  'other_x',
#  'cmp_passing_types_x',
#  'off_passing_types_x',
#  'out.1_x',
#  'int_passing_types_x',
#  'blocks_passing_types_x',
#  'sca_x',
#  'passlive_x',
#  'passdead_x',
#  'drib_x',
#  'sh_gca_x',
#  'fld_gca_x',
#  'def_x',
#  'gca_x',
#  'passlive.1_x',
#  'passdead.1_x',
#  'drib.1_x',
#  'sh_gca.1_x',
#  'fld_gca.1_x',
#  'def.1_x',
#  'tkl_x',
#  'tklw_defense_x',
#  'def 3rd_defense_x',
#  'mid 3rd_defense_x',
#  'att 3rd_defense_x',
#  'tkl.1_x',
#  'att_defense_x',
#  'tkl%_x',
#  'past_x',
#  'press_defense_x',
#  'succ_defense_x',
#  '%_x',
#  'def 3rd_defense.1_x',
#  'mid 3rd_defense.1_x',
#  'att 3rd_defense.1_x',
#  'blocks_defense_x',
#  'sh_defense_x',
#  'shsv_x',
#  'pass_x',
#  'int_defense_x',
#  'clr_x',
#  'err_x',
#  'poss_x',
#  'touches_x',
#  'def pen_x',
#  'def 3rd_possession_x',
#  'mid 3rd_possession_x',
#  'att 3rd_possession_x',
#  'att pen_x',
#  'live_possession_x',
#  'succ_possession_x',
#  'att_possession_x',
#  'succ%_x',
#  '#pl_x',
#  'megs_x',
#  'carries_x',
#  'totdist_possession_x',
#  'prgdist_possession_x',
#  'prog_possession_x',
#  '1/3_possession_x',
#  'cpa_x',
#  'mis_x',
#  'dis_x',
#  'targ_x',
#  'rec_x',
#  'rec%_x',
#  'prog_possession.1_x',
#  'crdy_x',
#  'crdr_x',
#  '2crdy_x',
#  'fls_x',
#  'fld_misc_x',
#  'off_misc_x',
#  'crs_misc_x',
#  'int_misc_x',
#  'tklw_misc_x',
#  'pkwon_x',
#  'pkcon_x',
#  'og_x',
#  'recov_x',
#  'won_x',
#  'lost_x',
#  'won%_x',
#  'team_x',
#  'season',
#  'month',
#  'year',
#  'weekday',
#  'NetScore',
#  'result_y',
#  'gf_y',
#  'ga_y',
#  'opponent_y',
#  'gls_y',
#  'sh_shooting_y',
#  'sot_y',
#  'sot%_y',
#  'g/sh_y',
#  'g/sot_y',
#  'dist_y',
#  'fk_shooting_y',
#  'pk_y',
#  'pkatt_shooting_y',
#  'xg_y',
#  'npxg_y',
#  'npxg/sh_y',
#  'g-xg_y',
#  'np:g-xg_y',
#  'sota_y',
#  'saves_y',
#  'save%_y',
#  'cs_y',
#  'psxg_y',
#  'psxg+/-_y',
#  'pkatt_keeper_y',
#  'pka_y',
#  'pksv_y',
#  'pkm_y',
#  'cmp_keeper_y',
#  'att_keeper_y',
#  'cmp%_keeper_y',
#  'att_keeper.1_y',
#  'thr_y',
#  'launch%_y',
#  'avglen_y',
#  'att_keeper.2_y',
#  'launch%.1_y',
#  'avglen.1_y',
#  'opp_y',
#  'stp_y',
#  'stp%_y',
#  '#opa_y',
#  'avgdist_y',
#  'cmp_passing_y',
#  'att_passing_y',
#  'cmp%_passing_y',
#  'totdist_passing_y',
#  'prgdist_passing_y',
#  'cmp_passing.1_y',
#  'att_passing.1_y',
#  'cmp%_passing.1_y',
#  'cmp_passing.2_y',
#  'att_passing.2_y',
#  'cmp%_passing.2_y',
#  'cmp_passing.3_y',
#  'att_passing.3_y',
#  'cmp%_passing.3_y',
#  'ast_y',
#  'xa_y',
#  'kp_y',
#  '1/3_passing_y',
#  'ppa_y',
#  'crspa_y',
#  'prog_passing_y',
#  'att_passing_types_y',
#  'live_passing_types_y',
#  'dead_y',
#  'fk_passing_types_y',
#  'tb_y',
#  'press_passing_types_y',
#  'sw_y',
#  'crs_passing_types_y',
#  'ck_y',
#  'in_y',
#  'out_y',
#  'str_y',
#  'ground_y',
#  'low_y',
#  'high_y',
#  'left_y',
#  'right_y',
#  'head_y',
#  'ti_y',
#  'other_y',
#  'cmp_passing_types_y',
#  'off_passing_types_y',
#  'out.1_y',
#  'int_passing_types_y',
#  'blocks_passing_types_y',
#  'sca_y',
#  'passlive_y',
#  'passdead_y',
#  'drib_y',
#  'sh_gca_y',
#  'fld_gca_y',
#  'def_y',
#  'gca_y',
#  'passlive.1_y',
#  'passdead.1_y',
#  'drib.1_y',
#  'sh_gca.1_y',
#  'fld_gca.1_y',
#  'def.1_y',
#  'tkl_y',
#  'tklw_defense_y',
#  'def 3rd_defense_y',
#  'mid 3rd_defense_y',
#  'att 3rd_defense_y',
#  'tkl.1_y',
#  'att_defense_y',
#  'tkl%_y',
#  'past_y',
#  'press_defense_y',
#  'succ_defense_y',
#  '%_y',
#  'def 3rd_defense.1_y',
#  'mid 3rd_defense.1_y',
#  'att 3rd_defense.1_y',
#  'blocks_defense_y',
#  'sh_defense_y',
#  'shsv_y',
#  'pass_y',
#  'int_defense_y',
#  'clr_y',
#  'err_y',
#  'poss_y',
#  'touches_y',
#  'def pen_y',
#  'def 3rd_possession_y',
#  'mid 3rd_possession_y',
#  'att 3rd_possession_y',
#  'att pen_y',
#  'live_possession_y',
#  'succ_possession_y',
#  'att_possession_y',
#  'succ%_y',
#  '#pl_y',
#  'megs_y',
#  'carries_y',
#  'totdist_possession_y',
#  'prgdist_possession_y',
#  'prog_possession_y',
#  '1/3_possession_y',
#  'cpa_y',
#  'mis_y',
#  'dis_y',
#  'targ_y',
#  'rec_y',
#  'rec%_y',
#  'prog_possession.1_y',
#  'crdy_y',
#  'crdr_y',
#  '2crdy_y',
#  'fls_y',
#  'fld_misc_y',
#  'off_misc_y',
#  'crs_misc_y',
#  'int_misc_y',
#  'tklw_misc_y',
#  'pkwon_y',
#  'pkcon_y',
#  'og_y',
#  'recov_y',
#  'won_y',
#  'lost_y',
#  'won%_y',
#  'team_y']

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
def do_RF(xs,y,valid_xs):
##############
    clf=RandomForestRegressor(random_state=42)
    clf.fit(xs,y)

    # clf.score(xs,y),clf.score(valid_xs,valid_y)
    pred_valid=clf.predict(valid_xs)
    pred=clf.predict(xs)
    
#     ppred_valid=clf.predict_proba(valid_xs)
#     ppred=clf.predict_proba(xs)
    
    return pred,pred_valid#,ppred,ppred_valid

   
def get_scores2(nom,predd, yy):

    prec=precision_score(predd, np.array(yy)) 
    acc=accuracy_score(predd, np.array(yy))

    print("{}: accuracy = {:.3f} and precision = {:.3f}".format(nom,acc,prec))
    
def get_reg_scores(yy,preds,XX):
    yy=copy.copy(yy)
    preds=copy.copy(preds)
    
    
    yy[yy>0] = 1
    yy[yy<=0] = 0
#     yy[yy==0]=0
#     yy[yy<0]=-1
    
    preds[preds>=XX]=1
    preds[preds<XX]=0
    
#     preds[preds<-XX]=-1
#     preds[( (preds>=-XX) & (preds<XX) )]=0
    

    get_scores2('Regression RF',preds, yy)
#     preds_yy=preds-yy
#     print( len(preds_yy[preds_yy==0])/len(yy) )

    return preds,yy

# %%
pred,pred_val=do_RF(xs,y,valid_xs)

# %%
new_preds,new_y=get_reg_scores(valid_y,pred_val,.5)
# Out:
# Regression RF: accuracy = 0.626 and precision = 0.368

# %%
to.show()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>opponent_x</th>
#       <th>team_x</th>
#       <th>opponent_y</th>
#       <th>team_y</th>
#       <th>result_x_na</th>
#       <th>gf_x_na</th>
#       <th>ga_x_na</th>
#       <th>gls_x_na</th>
#       <th>sh_shooting_x_na</th>
#       <th>sot_x_na</th>
#       <th>sot%_x_na</th>
#       <th>g/sh_x_na</th>
#       <th>g/sot_x_na</th>
#       <th>dist_x_na</th>
#       <th>fk_shooting_x_na</th>
#       <th>pk_x_na</th>
#       <th>pkatt_shooting_x_na</th>
#       <th>xg_x_na</th>
#       <th>npxg_x_na</th>
#       <th>npxg/sh_x_na</th>
#       <th>g-xg_x_na</th>
#       <th>np:g-xg_x_na</th>
#       <th>sota_x_na</th>
#       <th>saves_x_na</th>
#       <th>save%_x_na</th>
#       <th>cs_x_na</th>
#       <th>psxg_x_na</th>
#       <th>psxg+/-_x_na</th>
#       <th>pkatt_keeper_x_na</th>
#       <th>pka_x_na</th>
#       <th>pksv_x_na</th>
#       <th>pkm_x_na</th>
#       <th>cmp_keeper_x_na</th>
#       <th>att_keeper_x_na</th>
#       <th>cmp%_keeper_x_na</th>
#       <th>att_keeper.1_x_na</th>
#       <th>thr_x_na</th>
#       <th>launch%_x_na</th>
#       <th>avglen_x_na</th>
#       <th>att_keeper.2_x_na</th>
#       <th>launch%.1_x_na</th>
#       <th>avglen.1_x_na</th>
#       <th>opp_x_na</th>
#       <th>stp_x_na</th>
#       <th>stp%_x_na</th>
#       <th>#opa_x_na</th>
#       <th>avgdist_x_na</th>
#       <th>cmp_passing_x_na</th>
#       <th>att_passing_x_na</th>
#       <th>cmp%_passing_x_na</th>
#       <th>totdist_passing_x_na</th>
#       <th>prgdist_passing_x_na</th>
#       <th>cmp_passing.1_x_na</th>
#       <th>att_passing.1_x_na</th>
#       <th>cmp%_passing.1_x_na</th>
#       <th>cmp_passing.2_x_na</th>
#       <th>att_passing.2_x_na</th>
#       <th>cmp%_passing.2_x_na</th>
#       <th>cmp_passing.3_x_na</th>
#       <th>att_passing.3_x_na</th>
#       <th>cmp%_passing.3_x_na</th>
#       <th>ast_x_na</th>
#       <th>xa_x_na</th>
#       <th>kp_x_na</th>
#       <th>1/3_passing_x_na</th>
#       <th>ppa_x_na</th>
#       <th>crspa_x_na</th>
#       <th>prog_passing_x_na</th>
#       <th>att_passing_types_x_na</th>
#       <th>live_passing_types_x_na</th>
#       <th>dead_x_na</th>
#       <th>fk_passing_types_x_na</th>
#       <th>tb_x_na</th>
#       <th>press_passing_types_x_na</th>
#       <th>sw_x_na</th>
#       <th>crs_passing_types_x_na</th>
#       <th>ck_x_na</th>
#       <th>in_x_na</th>
#       <th>out_x_na</th>
#       <th>str_x_na</th>
#       <th>ground_x_na</th>
#       <th>low_x_na</th>
#       <th>high_x_na</th>
#       <th>left_x_na</th>
#       <th>right_x_na</th>
#       <th>head_x_na</th>
#       <th>ti_x_na</th>
#       <th>other_x_na</th>
#       <th>cmp_passing_types_x_na</th>
#       <th>off_passing_types_x_na</th>
#       <th>out.1_x_na</th>
#       <th>int_passing_types_x_na</th>
#       <th>blocks_passing_types_x_na</th>
#       <th>sca_x_na</th>
#       <th>passlive_x_na</th>
#       <th>passdead_x_na</th>
#       <th>drib_x_na</th>
#       <th>sh_gca_x_na</th>
#       <th>fld_gca_x_na</th>
#       <th>def_x_na</th>
#       <th>gca_x_na</th>
#       <th>passlive.1_x_na</th>
#       <th>passdead.1_x_na</th>
#       <th>drib.1_x_na</th>
#       <th>sh_gca.1_x_na</th>
#       <th>fld_gca.1_x_na</th>
#       <th>def.1_x_na</th>
#       <th>tkl_x_na</th>
#       <th>tklw_defense_x_na</th>
#       <th>def 3rd_defense_x_na</th>
#       <th>mid 3rd_defense_x_na</th>
#       <th>att 3rd_defense_x_na</th>
#       <th>tkl.1_x_na</th>
#       <th>att_defense_x_na</th>
#       <th>tkl%_x_na</th>
#       <th>past_x_na</th>
#       <th>press_defense_x_na</th>
#       <th>succ_defense_x_na</th>
#       <th>%_x_na</th>
#       <th>def 3rd_defense.1_x_na</th>
#       <th>mid 3rd_defense.1_x_na</th>
#       <th>att 3rd_defense.1_x_na</th>
#       <th>blocks_defense_x_na</th>
#       <th>sh_defense_x_na</th>
#       <th>shsv_x_na</th>
#       <th>pass_x_na</th>
#       <th>int_defense_x_na</th>
#       <th>clr_x_na</th>
#       <th>err_x_na</th>
#       <th>poss_x_na</th>
#       <th>touches_x_na</th>
#       <th>def pen_x_na</th>
#       <th>def 3rd_possession_x_na</th>
#       <th>mid 3rd_possession_x_na</th>
#       <th>att 3rd_possession_x_na</th>
#       <th>att pen_x_na</th>
#       <th>live_possession_x_na</th>
#       <th>succ_possession_x_na</th>
#       <th>att_possession_x_na</th>
#       <th>succ%_x_na</th>
#       <th>#pl_x_na</th>
#       <th>megs_x_na</th>
#       <th>carries_x_na</th>
#       <th>totdist_possession_x_na</th>
#       <th>prgdist_possession_x_na</th>
#       <th>prog_possession_x_na</th>
#       <th>1/3_possession_x_na</th>
#       <th>cpa_x_na</th>
#       <th>mis_x_na</th>
#       <th>dis_x_na</th>
#       <th>targ_x_na</th>
#       <th>rec_x_na</th>
#       <th>rec%_x_na</th>
#       <th>prog_possession.1_x_na</th>
#       <th>crdy_x_na</th>
#       <th>crdr_x_na</th>
#       <th>2crdy_x_na</th>
#       <th>fls_x_na</th>
#       <th>fld_misc_x_na</th>
#       <th>off_misc_x_na</th>
#       <th>crs_misc_x_na</th>
#       <th>int_misc_x_na</th>
#       <th>tklw_misc_x_na</th>
#       <th>pkwon_x_na</th>
#       <th>pkcon_x_na</th>
#       <th>og_x_na</th>
#       <th>recov_x_na</th>
#       <th>won_x_na</th>
#       <th>lost_x_na</th>
#       <th>won%_x_na</th>
#       <th>result_y_na</th>
#       <th>gf_y_na</th>
#       <th>ga_y_na</th>
#       <th>gls_y_na</th>
#       <th>sh_shooting_y_na</th>
#       <th>sot_y_na</th>
#       <th>sot%_y_na</th>
#       <th>g/sh_y_na</th>
#       <th>g/sot_y_na</th>
#       <th>dist_y_na</th>
#       <th>fk_shooting_y_na</th>
#       <th>pk_y_na</th>
#       <th>pkatt_shooting_y_na</th>
#       <th>xg_y_na</th>
#       <th>npxg_y_na</th>
#       <th>npxg/sh_y_na</th>
#       <th>g-xg_y_na</th>
#       <th>np:g-xg_y_na</th>
#       <th>sota_y_na</th>
#       <th>saves_y_na</th>
#       <th>save%_y_na</th>
#       <th>cs_y_na</th>
#       <th>psxg_y_na</th>
#       <th>psxg+/-_y_na</th>
#       <th>pkatt_keeper_y_na</th>
#       <th>pka_y_na</th>
#       <th>pksv_y_na</th>
#       <th>pkm_y_na</th>
#       <th>cmp_keeper_y_na</th>
#       <th>att_keeper_y_na</th>
#       <th>cmp%_keeper_y_na</th>
#       <th>att_keeper.1_y_na</th>
#       <th>thr_y_na</th>
#       <th>launch%_y_na</th>
#       <th>avglen_y_na</th>
#       <th>att_keeper.2_y_na</th>
#       <th>launch%.1_y_na</th>
#       <th>avglen.1_y_na</th>
#       <th>opp_y_na</th>
#       <th>stp_y_na</th>
#       <th>stp%_y_na</th>
#       <th>#opa_y_na</th>
#       <th>avgdist_y_na</th>
#       <th>cmp_passing_y_na</th>
#       <th>att_passing_y_na</th>
#       <th>cmp%_passing_y_na</th>
#       <th>totdist_passing_y_na</th>
#       <th>prgdist_passing_y_na</th>
#       <th>cmp_passing.1_y_na</th>
#       <th>att_passing.1_y_na</th>
#       <th>cmp%_passing.1_y_na</th>
#       <th>cmp_passing.2_y_na</th>
#       <th>att_passing.2_y_na</th>
#       <th>cmp%_passing.2_y_na</th>
#       <th>cmp_passing.3_y_na</th>
#       <th>att_passing.3_y_na</th>
#       <th>cmp%_passing.3_y_na</th>
#       <th>ast_y_na</th>
#       <th>xa_y_na</th>
#       <th>kp_y_na</th>
#       <th>1/3_passing_y_na</th>
#       <th>ppa_y_na</th>
#       <th>crspa_y_na</th>
#       <th>prog_passing_y_na</th>
#       <th>att_passing_types_y_na</th>
#       <th>live_passing_types_y_na</th>
#       <th>dead_y_na</th>
#       <th>fk_passing_types_y_na</th>
#       <th>tb_y_na</th>
#       <th>press_passing_types_y_na</th>
#       <th>sw_y_na</th>
#       <th>crs_passing_types_y_na</th>
#       <th>ck_y_na</th>
#       <th>in_y_na</th>
#       <th>out_y_na</th>
#       <th>str_y_na</th>
#       <th>ground_y_na</th>
#       <th>low_y_na</th>
#       <th>high_y_na</th>
#       <th>left_y_na</th>
#       <th>right_y_na</th>
#       <th>head_y_na</th>
#       <th>ti_y_na</th>
#       <th>other_y_na</th>
#       <th>cmp_passing_types_y_na</th>
#       <th>off_passing_types_y_na</th>
#       <th>out.1_y_na</th>
#       <th>int_passing_types_y_na</th>
#       <th>blocks_passing_types_y_na</th>
#       <th>sca_y_na</th>
#       <th>passlive_y_na</th>
#       <th>passdead_y_na</th>
#       <th>drib_y_na</th>
#       <th>sh_gca_y_na</th>
#       <th>fld_gca_y_na</th>
#       <th>def_y_na</th>
#       <th>gca_y_na</th>
#       <th>passlive.1_y_na</th>
#       <th>passdead.1_y_na</th>
#       <th>drib.1_y_na</th>
#       <th>sh_gca.1_y_na</th>
#       <th>fld_gca.1_y_na</th>
#       <th>def.1_y_na</th>
#       <th>tkl_y_na</th>
#       <th>tklw_defense_y_na</th>

# %%
def do_XGB(n_estimators=1000, learning_rate=0.0001, n_jobs=100):
    from xgboost import XGBRegressor
    # !pip install xgboost
    

    # Define the model
    my_model_2 = XGBRegressor(n_estimators=1000, learning_rate=0.01) # Your code here

    # Fit the model
    my_model_2.fit(xs, y) 

    # Get predictions
#     ppred = my_model_2.predict_proba(xs)
#     ppred_valid = my_model_2.predict_probab(valid_xs)
    
    pred = my_model_2.predict(xs)
    pred_valid = my_model_2.predict(valid_xs)
    XX=0.5
    pred[pred>=XX]=1
    pred[pred<XX]=0

    return pred,pred_valid 

   


# pred_RF,pred_valid_RF, ppred_RF,ppred_valid_RF  = do_RF()
pred_XGB,pred_valid_XGB = do_XGB()
# pred_rdg,pred_valid_rdg,ppred_rdg,ppred_valid_rdg = do_ridge()

# %%
get_reg_scores(valid_y,0.5*(pred_valid_XGB+pred_val),.5);
# len(pred_XGB),len(valid_y)
# precision_score(valid_y,pred_val)
# Out:
# Regression RF: accuracy = 0.624 and precision = 0.368

# %%
clf=RandomForestRegressor(random_state=42)
clf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
#collapse-hide
# Number of trees in random forest
n_estimators=[20,50,150,400,700]

# Number of features to consider at every split
# max_features = ['log2','sqrt',None]

# Maximum number of levels in tree
max_depth=[10,  30,  70,  200, None]

# Minimum number of samples required to split a node
min_samples_split = [1.,2, 10,50]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4,10]

# Method of selecting samples for training each tree
# bootstrap = [True, False]

# Weights associated with classes 
class_weight=["balanced", "balanced_subsample",None]

#Complexity parameter used for Minimal Cost-Complexity Pruning.
ccp_alpha=[0., 0.1, 0.5]

random_grid = {'n_estimators': n_estimators,
#                'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
#                'bootstrap': bootstrap,
#                'class_weight':class_weight,
               'ccp_alpha' : ccp_alpha

              }

rsh = HalvingRandomSearchCV(estimator = clf, param_distributions = random_grid, \
                              random_state=42, factor = 3)# Fit the random search model
rsh.fit(xs, y)
# Out:
# HalvingRandomSearchCV(estimator=RandomForestRegressor(random_state=42),
#                       param_distributions={'ccp_alpha': [0.0, 0.1, 0.5],
#                                            'max_depth': [10, 30, 70, 200, None],
#                                            'min_samples_leaf': [1, 2, 4, 10],
#                                            'min_samples_split': [1.0, 2, 10,
#                                                                  50],
#                                            'n_estimators': [20, 50, 150, 400,
#                                                             700]},
#                       random_state=42)

# %%
pred=rsh.predict(xs)
pred_valid=rsh.predict(valid_xs)

get_reg_scores(valid_y,pred_valid,.5);

get_reg_scores(valid_y,0.5*(pred_valid_XGB+pred_valid),.5);

# valid_y,pred_valid

# pred = rsh.predict(xs)
# pred_valid = my_model_2.predict(valid_xs)
# XX=0.5
# pred[pred>=XX]=1
# pred[pred<XX]=0
# Out:
# Regression RF: accuracy = 0.626 and precision = 0.350
# Regression RF: accuracy = 0.621 and precision = 0.350

# %%
df.loc[:,'Win']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Win'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16004/2658962484.py in <module>
# ----> 1 df.loc[:,'Win']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1058     def _getitem_tuple(self, tup: Tuple):
#    1059         with suppress(IndexingError):
# -> 1060             return self._getitem_lowerdim(tup)
#    1061
#    1062         # no multi-index, so validate all of the indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     805                 # We don't need to check for tuples here because those are
#     806                 #  caught by the _is_nested_tuple_indexer check above.
# --> 807                 section = self._getitem_axis(key, axis=i)
#     808
#     809                 # We should never have a scalar section here, because
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1122         # fall thru to straight lookup
#    1123         self._validate_key(key, axis)
# -> 1124         return self._get_label(key, axis=axis)
#    1125
#    1126     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1071     def _get_label(self, label, axis: int):
#    1072         # GH#5667 this will fail if the label is not present in the axis.
# -> 1073         return self.obj.xs(label, axis=axis)
#    1074
#    1075     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3722         if axis == 1:
#    3723             if drop_level:
# -> 3724                 return self[key]
#    3725             index = self.columns
#    3726         else:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'Win'

# %%
matchesC=pd.read_csv(folda+'epl2017-2021_wivnetscore.csv')

X=matchesC.corr()
val =[ i for i,x in enumerate(X.columns) if x=='NetScore_x'][0]

corrnetscore=X.iloc[:,val:val+1].sort_values(by="NetScore_x").reset_index()
corrnetscore=corrnetscore.rename(columns={'index':'category'})

# %%
Xuse=corrnetscore.loc[[x   for x in corrnetscore.index if ( (corrnetscore.loc[x,'category'][-1]=='x') & ( abs(corrnetscore.loc[x,'NetScore_x'])>0.27) )]]
Xuse=list(Xuse[-15:-1].category.values)
Xuse
# Out:
# ['att_passing.2_x',
#  'totdist_passing_x',
#  'touches_x',
#  'cmp_passing_types_x',
#  'cmp_passing_x',
#  'rec_x',
#  'targ_x',
#  'live_possession_x',
#  'prog_possession_x',
#  'att_passing_types_x',
#  'att_passing_x',
#  'carries_x',
#  'live_passing_types_x',
#  'mid 3rd_possession_x']

# %%
Xuse
# Out:
# ['att_passing_types_x',
#  'att_passing_x',
#  'carries_x',
#  'live_passing_types_x',
#  'mid 3rd_possession_x']

# %%
df_=pd.read_csv(folda+'epl2017-2021.csv')

df_=df_.iloc[10:,:]
cols = ["gf","ga","sh_shooting","sot","dist","fk_shooting","pk","pkatt_shooting"]
def dowin(string):
    if string=='W':
        return 1
    else:
        return 0
df_['Win_x']=df_['Win_x'].apply(dowin)
predictors = [x+'_x' for x in cols ]

predictors=Xuse.copy()

predictors_=['day','opponent_x','team_x','weekday']

[predictors.append(x) for x in predictors_]

df_["opponent_x"] = df_["opponent_x"].astype("category").cat.codes
df_["team_x"] = df_["team_x"].astype("category").cat.codes

predictors.append('Win_x')
predictors.append('season')
# df.loc[:,cola]

# [x for x in df.columns if x[0]=='W']

df=df_.copy()
df=df.loc[:,predictors]
df=df.dropna()

train = df.loc[df["season"] <= 2020,:]
test = df.loc[df["season"] > 2020,:]

print(len(train) , len(test))
# RandomForestClassifie
rf = RandomForestClassifier()#n_estimators = 40, min_samples_split =10, random_state = 1)
print(predictors[0:-2])
predictors=predictors[0:-2]
rf.fit(train[predictors], train['Win_x'])
pred = rf.predict(test[predictors])

print(accuracy_score(test['Win_x'], pred),precision_score(test['Win_x'], pred) )
# Out:
# 1508 379
# ['att_passing.2_x', 'totdist_passing_x', 'touches_x', 'cmp_passing_types_x', 'cmp_passing_x', 'rec_x', 'targ_x', 'live_possession_x', 'prog_possession_x', 'att_passing_types_x', 'att_passing_x', 'carries_x', 'live_passing_types_x', 'mid 3rd_possession_x', 'day', 'opponent_x', 'team_x', 'weekday']
# 0.6358839050131926 0.6052631578947368

# %%
df=df_.copy()
df=df.dropna()
train = df[df["season"] <= 2020]
test = df[df["season"] > 2020]

[predictors.append(x) for x in predictors_]
predictors.append('Win_x')
predictors.append('season')
predictors=predictors[0:-2]
rf.fit(train[predictors], train['Win_x'])
pred = rf.predict(test[predictors])
accuracy_score(test['Win_x'], pred)
# Out:
# 0.6464379947229552

# %%
# Out:
# ['rec_x',
#  'targ_x',
#  'live_possession_x',
#  'prog_possession_x',
#  'att_passing_types_x',
#  'att_passing_x',
#  'carries_x',
#  'live_passing_types_x',
#  'mid 3rd_possession_x',
#  'day',
#  'opponent_x',
#  'team_x',
#  'weekday',
#  'day',
#  'opponent_x',
#  'team_x',
#  'weekday']

# %%
df=pd.read_csv(folda+'epl2017-2021.csv')
cola=['day','opponent_x','team_x','weekday','season']
df.loc[:,cola[3]]
[x for x in df.columns]
# Out:
# ['Unnamed: 0',
#  'round',
#  'day',
#  'result_x',
#  'gf_x',
#  'ga_x',
#  'opponent_x',
#  'gls_x',
#  'sh_shooting_x',
#  'sot_x',
#  'sot%_x',
#  'g/sh_x',
#  'g/sot_x',
#  'dist_x',
#  'fk_shooting_x',
#  'pk_x',
#  'pkatt_shooting_x',
#  'xg_x',
#  'npxg_x',
#  'npxg/sh_x',
#  'g-xg_x',
#  'np:g-xg_x',
#  'sota_x',
#  'saves_x',
#  'save%_x',
#  'cs_x',
#  'psxg_x',
#  'psxg+/-_x',
#  'pkatt_keeper_x',
#  'pka_x',
#  'pksv_x',
#  'pkm_x',
#  'cmp_keeper_x',
#  'att_keeper_x',
#  'cmp%_keeper_x',
#  'att_keeper.1_x',
#  'thr_x',
#  'launch%_x',
#  'avglen_x',
#  'att_keeper.2_x',
#  'launch%.1_x',
#  'avglen.1_x',
#  'opp_x',
#  'stp_x',
#  'stp%_x',
#  '#opa_x',
#  'avgdist_x',
#  'cmp_passing_x',
#  'att_passing_x',
#  'cmp%_passing_x',
#  'totdist_passing_x',
#  'prgdist_passing_x',
#  'cmp_passing.1_x',
#  'att_passing.1_x',
#  'cmp%_passing.1_x',
#  'cmp_passing.2_x',
#  'att_passing.2_x',
#  'cmp%_passing.2_x',
#  'cmp_passing.3_x',
#  'att_passing.3_x',
#  'cmp%_passing.3_x',
#  'ast_x',
#  'xa_x',
#  'kp_x',
#  '1/3_passing_x',
#  'ppa_x',
#  'crspa_x',
#  'prog_passing_x',
#  'att_passing_types_x',
#  'live_passing_types_x',
#  'dead_x',
#  'fk_passing_types_x',
#  'tb_x',
#  'press_passing_types_x',
#  'sw_x',
#  'crs_passing_types_x',
#  'ck_x',
#  'in_x',
#  'out_x',
#  'str_x',
#  'ground_x',
#  'low_x',
#  'high_x',
#  'left_x',
#  'right_x',
#  'head_x',
#  'ti_x',
#  'other_x',
#  'cmp_passing_types_x',
#  'off_passing_types_x',
#  'out.1_x',
#  'int_passing_types_x',
#  'blocks_passing_types_x',
#  'sca_x',
#  'passlive_x',
#  'passdead_x',
#  'drib_x',
#  'sh_gca_x',
#  'fld_gca_x',
#  'def_x',
#  'gca_x',
#  'passlive.1_x',
#  'passdead.1_x',
#  'drib.1_x',
#  'sh_gca.1_x',
#  'fld_gca.1_x',
#  'def.1_x',
#  'tkl_x',
#  'tklw_defense_x',
#  'def 3rd_defense_x',
#  'mid 3rd_defense_x',
#  'att 3rd_defense_x',
#  'tkl.1_x',
#  'att_defense_x',
#  'tkl%_x',
#  'past_x',
#  'press_defense_x',
#  'succ_defense_x',
#  '%_x',
#  'def 3rd_defense.1_x',
#  'mid 3rd_defense.1_x',
#  'att 3rd_defense.1_x',
#  'blocks_defense_x',
#  'sh_defense_x',
#  'shsv_x',
#  'pass_x',
#  'int_defense_x',
#  'clr_x',
#  'err_x',
#  'poss_x',
#  'touches_x',
#  'def pen_x',
#  'def 3rd_possession_x',
#  'mid 3rd_possession_x',
#  'att 3rd_possession_x',
#  'att pen_x',
#  'live_possession_x',
#  'succ_possession_x',
#  'att_possession_x',
#  'succ%_x',
#  '#pl_x',
#  'megs_x',
#  'carries_x',
#  'totdist_possession_x',
#  'prgdist_possession_x',
#  'prog_possession_x',
#  '1/3_possession_x',
#  'cpa_x',
#  'mis_x',
#  'dis_x',
#  'targ_x',
#  'rec_x',
#  'rec%_x',
#  'prog_possession.1_x',
#  'crdy_x',
#  'crdr_x',
#  '2crdy_x',
#  'fls_x',
#  'fld_misc_x',
#  'off_misc_x',
#  'crs_misc_x',
#  'int_misc_x',
#  'tklw_misc_x',
#  'pkwon_x',
#  'pkcon_x',
#  'og_x',
#  'recov_x',
#  'won_x',
#  'lost_x',
#  'won%_x',
#  'team_x',
#  'season',
#  'month',
#  'year',
#  'weekday',
#  'Win_x',
#  'result_y',
#  'gf_y',
#  'ga_y',
#  'opponent_y',
#  'gls_y',
#  'sh_shooting_y',
#  'sot_y',
#  'sot%_y',
#  'g/sh_y',
#  'g/sot_y',
#  'dist_y',
#  'fk_shooting_y',
#  'pk_y',
#  'pkatt_shooting_y',
#  'xg_y',
#  'npxg_y',
#  'npxg/sh_y',
#  'g-xg_y',
#  'np:g-xg_y',
#  'sota_y',
#  'saves_y',
#  'save%_y',
#  'cs_y',
#  'psxg_y',
#  'psxg+/-_y',
#  'pkatt_keeper_y',
#  'pka_y',
#  'pksv_y',
#  'pkm_y',
#  'cmp_keeper_y',
#  'att_keeper_y',
#  'cmp%_keeper_y',
#  'att_keeper.1_y',
#  'thr_y',
#  'launch%_y',
#  'avglen_y',
#  'att_keeper.2_y',
#  'launch%.1_y',
#  'avglen.1_y',
#  'opp_y',
#  'stp_y',
#  'stp%_y',
#  '#opa_y',
#  'avgdist_y',
#  'cmp_passing_y',
#  'att_passing_y',
#  'cmp%_passing_y',
#  'totdist_passing_y',
#  'prgdist_passing_y',
#  'cmp_passing.1_y',
#  'att_passing.1_y',
#  'cmp%_passing.1_y',
#  'cmp_passing.2_y',
#  'att_passing.2_y',
#  'cmp%_passing.2_y',
#  'cmp_passing.3_y',
#  'att_passing.3_y',
#  'cmp%_passing.3_y',
#  'ast_y',
#  'xa_y',
#  'kp_y',
#  '1/3_passing_y',
#  'ppa_y',
#  'crspa_y',
#  'prog_passing_y',
#  'att_passing_types_y',
#  'live_passing_types_y',
#  'dead_y',
#  'fk_passing_types_y',
#  'tb_y',
#  'press_passing_types_y',
#  'sw_y',
#  'crs_passing_types_y',
#  'ck_y',
#  'in_y',
#  'out_y',
#  'str_y',
#  'ground_y',
#  'low_y',
#  'high_y',
#  'left_y',
#  'right_y',
#  'head_y',
#  'ti_y',
#  'other_y',
#  'cmp_passing_types_y',
#  'off_passing_types_y',
#  'out.1_y',
#  'int_passing_types_y',
#  'blocks_passing_types_y',
#  'sca_y',
#  'passlive_y',
#  'passdead_y',
#  'drib_y',
#  'sh_gca_y',
#  'fld_gca_y',
#  'def_y',
#  'gca_y',
#  'passlive.1_y',
#  'passdead.1_y',
#  'drib.1_y',
#  'sh_gca.1_y',
#  'fld_gca.1_y',
#  'def.1_y',
#  'tkl_y',
#  'tklw_defense_y',
#  'def 3rd_defense_y',
#  'mid 3rd_defense_y',
#  'att 3rd_defense_y',
#  'tkl.1_y',
#  'att_defense_y',
#  'tkl%_y',
#  'past_y',
#  'press_defense_y',
#  'succ_defense_y',
#  '%_y',
#  'def 3rd_defense.1_y',
#  'mid 3rd_defense.1_y',
#  'att 3rd_defense.1_y',
#  'blocks_defense_y',
#  'sh_defense_y',
#  'shsv_y',
#  'pass_y',
#  'int_defense_y',
#  'clr_y',
#  'err_y',
#  'poss_y',
#  'touches_y',
#  'def pen_y',
#  'def 3rd_possession_y',
#  'mid 3rd_possession_y',
#  'att 3rd_possession_y',
#  'att pen_y',
#  'live_possession_y',
#  'succ_possession_y',
#  'att_possession_y',
#  'succ%_y',
#  '#pl_y',
#  'megs_y',
#  'carries_y',
#  'totdist_possession_y',
#  'prgdist_possession_y',
#  'prog_possession_y',
#  '1/3_possession_y',
#  'cpa_y',
#  'mis_y',
#  'dis_y',
#  'targ_y',
#  'rec_y',
#  'rec%_y',
#  'prog_possession.1_y',
#  'crdy_y',
#  'crdr_y',
#  '2crdy_y',
#  'fls_y',
#  'fld_misc_y',
#  'off_misc_y',
#  'crs_misc_y',
#  'int_misc_y',
#  'tklw_misc_y',
#  'pkwon_y',
#  'pkcon_y',
#  'og_y',
#  'recov_y',
#  'won_y',
#  'lost_y',
#  'won%_y',
#  'team_y']

# %%
mg = df.groupby('team_x').mean()
mg
# df
# Out:
#               day  opponent_x   weekday      gf_x      ga_x  sh_shooting_x  \
# team_x
# 0       15.148936   14.117021  4.638298  1.602837  1.248227      12.836879
# 1       16.578947   14.000000  4.350877  1.245614  1.511696      12.248538
# 2       15.719298   14.052632  4.526316  1.192982  1.809942      11.023392
# 3       16.888889   14.388889  4.888889  1.222222  1.592593      11.185185
# 4       16.340426   13.882979  4.148936  0.996454  1.322695      11.234043
# 5       15.610526   13.842105  4.168421  1.000000  1.414035       9.796491
# 6       15.421053   13.210526  4.684211  0.807018  1.894737      10.701754
# 7       15.489362   13.829787  4.202128  1.744681  1.099291      15.320922
# 8       16.882979   13.712766  4.234043  1.141844  1.446809      10.615248
# 9       13.829787   13.553191  4.287234  1.187943  1.418440      11.085106
# 2       0.350877  2018.000000
# 3       0.333333  2021.000000
# 4       0.287234  2019.021277
# 5       0.326316  2019.000000
# 6       0.315789  2018.000000
# 7       0.553191  2019.021277
# 8       0.329787  2019.021277
# 9       0.446809  2019.021277
# 10      0.216216  2019.027027
# 11      0.210526  2017.500000
# 12      0.315789  2020.500000
# 13      0.473684  2019.000000
# 14      0.757895  2019.000000
# 15      0.810526  2019.000000
# 16      0.563830  2019.021277
# 17      0.382979  2019.021277
# 18      0.184211  2020.000000
# 19      0.394737  2019.500000
# 20      0.308511  2019.021277
# 21      0.263158  2017.000000
# 22      0.315789  2017.000000
# 23      0.631579  2019.000000
# 24      0.306667  2018.773333
# 25      0.135135  2018.540541
# 26      0.431579  2019.000000
# 27      0.426667  2019.520000

# %%
# plt.plot(mg.Win_x,mg.dist_x,'ok')
[x for x in df_.columns if x[-1]!='y']
# Out:
# ['Unnamed: 0',
#  'round',
#  'result_x',
#  'gf_x',
#  'ga_x',
#  'opponent_x',
#  'gls_x',
#  'sh_shooting_x',
#  'sot_x',
#  'sot%_x',
#  'g/sh_x',
#  'g/sot_x',
#  'dist_x',
#  'fk_shooting_x',
#  'pk_x',
#  'pkatt_shooting_x',
#  'xg_x',
#  'npxg_x',
#  'npxg/sh_x',
#  'g-xg_x',
#  'np:g-xg_x',
#  'sota_x',
#  'saves_x',
#  'save%_x',
#  'cs_x',
#  'psxg_x',
#  'psxg+/-_x',
#  'pkatt_keeper_x',
#  'pka_x',
#  'pksv_x',
#  'pkm_x',
#  'cmp_keeper_x',
#  'att_keeper_x',
#  'cmp%_keeper_x',
#  'att_keeper.1_x',
#  'thr_x',
#  'launch%_x',
#  'avglen_x',
#  'att_keeper.2_x',
#  'launch%.1_x',
#  'avglen.1_x',
#  'opp_x',
#  'stp_x',
#  'stp%_x',
#  '#opa_x',
#  'avgdist_x',
#  'cmp_passing_x',
#  'att_passing_x',
#  'cmp%_passing_x',
#  'totdist_passing_x',
#  'prgdist_passing_x',
#  'cmp_passing.1_x',
#  'att_passing.1_x',
#  'cmp%_passing.1_x',
#  'cmp_passing.2_x',
#  'att_passing.2_x',
#  'cmp%_passing.2_x',
#  'cmp_passing.3_x',
#  'att_passing.3_x',
#  'cmp%_passing.3_x',
#  'ast_x',
#  'xa_x',
#  'kp_x',
#  '1/3_passing_x',
#  'ppa_x',
#  'crspa_x',
#  'prog_passing_x',
#  'att_passing_types_x',
#  'live_passing_types_x',
#  'dead_x',
#  'fk_passing_types_x',
#  'tb_x',
#  'press_passing_types_x',
#  'sw_x',
#  'crs_passing_types_x',
#  'ck_x',
#  'in_x',
#  'out_x',
#  'str_x',
#  'ground_x',
#  'low_x',
#  'high_x',
#  'left_x',
#  'right_x',
#  'head_x',
#  'ti_x',
#  'other_x',
#  'cmp_passing_types_x',
#  'off_passing_types_x',
#  'out.1_x',
#  'int_passing_types_x',
#  'blocks_passing_types_x',
#  'sca_x',
#  'passlive_x',
#  'passdead_x',
#  'drib_x',
#  'sh_gca_x',
#  'fld_gca_x',
#  'def_x',
#  'gca_x',
#  'passlive.1_x',
#  'passdead.1_x',
#  'drib.1_x',
#  'sh_gca.1_x',
#  'fld_gca.1_x',
#  'def.1_x',
#  'tkl_x',
#  'tklw_defense_x',
#  'def 3rd_defense_x',
#  'mid 3rd_defense_x',
#  'att 3rd_defense_x',
#  'tkl.1_x',
#  'att_defense_x',
#  'tkl%_x',
#  'past_x',
#  'press_defense_x',
#  'succ_defense_x',
#  '%_x',
#  'def 3rd_defense.1_x',
#  'mid 3rd_defense.1_x',
#  'att 3rd_defense.1_x',
#  'blocks_defense_x',
#  'sh_defense_x',
#  'shsv_x',
#  'pass_x',
#  'int_defense_x',
#  'clr_x',
#  'err_x',
#  'poss_x',
#  'touches_x',
#  'def pen_x',
#  'def 3rd_possession_x',
#  'mid 3rd_possession_x',
#  'att 3rd_possession_x',
#  'att pen_x',
#  'live_possession_x',
#  'succ_possession_x',
#  'att_possession_x',
#  'succ%_x',
#  '#pl_x',
#  'megs_x',
#  'carries_x',
#  'totdist_possession_x',
#  'prgdist_possession_x',
#  'prog_possession_x',
#  '1/3_possession_x',
#  'cpa_x',
#  'mis_x',
#  'dis_x',
#  'targ_x',
#  'rec_x',
#  'rec%_x',
#  'prog_possession.1_x',
#  'crdy_x',
#  'crdr_x',
#  '2crdy_x',
#  'fls_x',
#  'fld_misc_x',
#  'off_misc_x',
#  'crs_misc_x',
#  'int_misc_x',
#  'tklw_misc_x',
#  'pkwon_x',
#  'pkcon_x',
#  'og_x',
#  'recov_x',
#  'won_x',
#  'lost_x',
#  'won%_x',
#  'team_x',
#  'season',
#  'month',
#  'year',
#  'Win_x']

# %%
plt.plot(df.Win_x
# Out:
#           gf_x      ga_x  sh_shooting_x     sot_x     dist_x  fk_shooting_x  \
# 10    2.000000  0.000000      14.000000  4.000000  19.400000       2.000000
# 11    2.000000  0.000000      18.000000  6.000000  18.400000       0.000000
# 12    3.000000  3.000000      13.000000  4.000000  13.500000       0.000000
# 13    3.000000  2.000000      10.000000  5.000000  12.600000       1.000000
# 14    3.000000  4.000000       6.000000  4.000000  10.300000       0.000000
# ...        ...       ...            ...       ...        ...            ...
# 1895  2.666667  0.333333      15.666667  6.333333  16.300000       0.000000
# 1896  1.333333  0.666667      14.666667  5.000000  15.300000       0.333333
# 1897  2.000000  1.666667      16.000000  5.000000  16.400000       1.000000
# 1898  1.000000  1.666667      13.000000  4.333333  15.066667       0.333333
# 1899  0.333333  2.333333       9.666667  2.333333  18.533333       0.333333
#
#           pk_x  pkatt_shooting_x  Win_x  season
# 10    0.000000          0.000000      0    2017
# 11    0.000000          0.000000      0    2017
# 12    1.000000          1.000000      1    2017
# 13    0.000000          0.000000      0    2017
# 14    0.000000          0.000000      1    2017
# ...        ...               ...    ...     ...
# 1895  0.333333          0.666667      1    2021
# 1896  0.333333          0.333333      1    2021
# 1897  0.000000          0.000000      0    2021
# 1898  0.000000          0.000000      0    2021
# 1899  0.000000          0.000000      0    2021
#
# [1887 rows x 10 columns]
